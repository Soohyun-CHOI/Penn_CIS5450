# %% [markdown]
# # Overview of Part I
#
# As we start our journey into Big Data Analytics, the first thing we need to do is **get the data** in the form we need for analysis!  We'll start with an overview of how to acquire and *wrangle* data.
#
# This notebook gives us a series of examples for:
#
# * Acquiring data from files and remote sources
# * Information extraction over HTML content
# * A basic "vocabulary" of operators over tables (the relational algebra)
#
# * "Data wrangling" or integration:
#   * Cleaning and filtering data, using rules and based operations
#   * Linking data across dataframes or relations
#   * The need for approximate match and record linking

# %% [markdown]
# ## The Motivating Question
# To illustrate the principles, we focus on the question of how old company CEOs and founders are.  The question was in part motivated by the following New York Times article:
#
# * Founders of Successful Tech Companies Are Mostly Middle-Aged: https://www.nytimes.com/2019/08/29/business/tech-start-up-founders-nest.html?searchResultPosition=2
#
# So let's test this hypothesis!

# %%
# Let's install some libraries useful for processing web data

# For string similarity
# !pip3 install py_stringsimjoin

# # lxml to parse xml tree
# !pip3 install lxml
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting py_stringsimjoin
#   Downloading py_stringsimjoin-0.3.2.tar.gz (1.1 MB)
#      |████████████████████████████████| 1.1 MB 13.7 MB/s
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from py_stringsimjoin) (1.1.0)
# Requirement already satisfied: pandas>=0.16.0 in /usr/local/lib/python3.7/dist-packages (from py_stringsimjoin) (1.3.5)
# Collecting PyPrind>=2.9.3
#   Downloading PyPrind-2.11.3-py2.py3-none-any.whl (8.4 kB)
# Collecting py_stringmatching>=0.2.1
#   Downloading py_stringmatching-0.4.2.tar.gz (661 kB)
#      |████████████████████████████████| 661 kB 39.0 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from py_stringsimjoin) (1.15.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.16.0->py_stringsimjoin) (2022.2.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.16.0->py_stringsimjoin) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.16.0->py_stringsimjoin) (1.21.6)
# Building wheels for collected packages: py-stringsimjoin, py-stringmatching
#   Building wheel for py-stringsimjoin (setup.py) ... done
#   Created wheel for py-stringsimjoin: filename=py_stringsimjoin-0.3.2-cp37-cp37m-linux_x86_64.whl size=3724101 sha256=69b9e8a5bd39e2909376ddefe69e5159a23e218d28e79540af51a9016478da66
#   Stored in directory: /root/.cache/pip/wheels/7c/0d/a4/c0a779a4d196bed8ed41ca12be09a93e158e4fc974b59f9fd5
#   Building wheel for py-stringmatching (setup.py) ... done
#   Created wheel for py-stringmatching: filename=py_stringmatching-0.4.2-cp37-cp37m-linux_x86_64.whl size=2055514 sha256=3ee205e0265add14247712cdc5cf179ae51bba4c0ffb7b8eb6e607b7c81a572f
#   Stored in directory: /root/.cache/pip/wheels/7e/12/86/46f9378ae730550dd2f89cad50880e70d66cabedd90074f2d2
# Successfully built py-stringsimjoin py-stringmatching
# Installing collected packages: PyPrind, py-stringmatching, py-stringsimjoin
# Successfully installed PyPrind-2.11.3 py-stringmatching-0.4.2 py-stringsimjoin-0.3.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (4.9.1)

# %%
# Imports we'll use through the notebook, collected here for simplicity

# For parsing dates and being able to compare
import datetime

# For fetching remote data
import urllib
import urllib.request

# Pandas dataframes and operations
import pandas as pd

# Numpy matrix and array operations
import numpy as np

# Sqlite is a simplistic database
import sqlite3

# Approximate string matching, see
import py_stringsimjoin as ssj
import py_stringmatching as sm

# Data visualization
import matplotlib

# %% [markdown]
# # Lecture Module 1: Acquiring Data
#
# To test our hypothesis, we might want:
#
# 1. A list of companies (and, for futher details, perhaps their lines of business)
# 2. A list of company CEOs
# 3. Ages of the CEOs
#
# We'll go through each of these using real data from the web.
#
# ### Reading Structured Data Sources
#
# Let's start by looking up data about companies.  An example of this is at:
#
# https://gist.githubusercontent.com/jvilledieu/c3afe5bc21da28880a30/raw/a344034b82a11433ba6f149afa47e57567d4a18f/Companies.csv
#
# which has some nicely detailed information about companies, their categories, when they were founded, etc.  Let's load this (remote) CSV file into a dataframe.

# %%
data = urllib.request.urlopen(\
       'https://gist.github.com/jvilledieu/c3afe5bc21da28880a30/raw/a344034b82a11433ba6f149afa47e57567d4a18f/Companies.csv')

company_data_df = pd.read_csv(data)

# %%
# Let's write it to SQL, and read it back

conn = sqlite3.connect('local.db')

company_data_df.to_sql("companies", conn, if_exists="replace", index=False)

pd.read_sql_query('select * from companies', conn)
# Out:
#                                                 permalink  \
# 0                                   /organization/waywire
# 1                         /organization/tv-communications
# 2                           /organization/rock-your-paper
# 3                          /organization/in-touch-network
# 4                                   /organization/n-plusn
# ...                                                   ...
# 47753                                 /organization/zzish
# 47754  /organization/zznode-science-and-technology-co-ltd
# 47755                           /organization/zzzzapp-com
# 47756                          /organization/a-list-games
# 47757                                     /organization/x
#
#                                 name                   homepage_url  \
# 0                           #waywire         http://www.waywire.com
# 1                 &TV Communications          http://enjoyandtv.com
# 2                  'Rock' Your Paper   http://www.rockyourpaper.org
# 3                  (In)Touch Network  http://www.InTouchNetwork.com
# 4                         +n (PlusN)               http://plusn.com
# ...                              ...                            ...
# 47753                          Zzish           http://www.zzish.com
# 47754  ZZNode Science and Technology          http://www.zznode.com
# 47755          Zzzzapp Wireless ltd.         http://www.zzzzapp.com
# 47756                  [a]list games      http://www.alistgames.com
# 47757                          [x+1]       http://www.xplusone.com/
#
#                                                                          category_list  \
# 0                                           |Entertainment|Politics|Social Media|News|
# 1                                                                              |Games|
# 2                                                               |Publishing|Education|
# 3      |Electronics|Guides|Coffee|Restaurants|Music|iPhone|Apps|Mobile|iOS|E-Commerce|
# 4                                                                           |Software|
# ...                                                                                ...
# 47753                    |Analytics|Gamification|Developer APIs|iOS|Android|Education|
# 47754                                                            |Enterprise Software|
# 47755                                    |Web Development|Advertising|Wireless|Mobile|
# 47756                                                                          |Games|
# 47757                                                            |Enterprise Software|
#
#                       market funding_total_usd     status country_code  \
# 0                      News         1 750 000    acquired          USA
# 1                      Games        4 000 000   operating          USA
# 2                 Publishing           40 000   operating          EST
# 3                Electronics        1 500 000   operating          GBR
# 4                  Software         1 200 000   operating          USA
# ...                      ...               ...        ...          ...
# 47753             Education           320 000   operating          GBR
# 47754   Enterprise Software         1 587 301   operating          CHN
# 47755       Web Development            97 398   operating          HRV
# 47756                 Games         9 300 000   operating         None
# 47757   Enterprise Software        45 000 000   operating          USA
#
#       state_code         region         city  funding_rounds  founded_at  \
# 0             NY  New York City     New York               1  01/06/2012
# 1             CA    Los Angeles  Los Angeles               2        None
# 2           None        Tallinn      Tallinn               1  26/10/2012
# 3           None         London       London               1  01/04/2011
# 4             NY  New York City     New York               2  01/01/2012
# ...          ...            ...          ...             ...         ...
# 47753       None         London       London               1  28/01/2013
# 47754       None        Beijing      Beijing               1        None
# 47755       None          Split        Split               5  13/05/2012
# 47756       None           None         None               1        None
# 47757         NY  New York City     New York               4  01/01/1999
#
#       founded_month founded_quarter  founded_year first_funding_at  \
# 0           2012-06         2012-Q2        2012.0       30/06/2012
# 1              None            None           NaN       04/06/2010
# 2           2012-10         2012-Q4        2012.0       09/08/2012
# 3           2011-04         2011-Q2        2011.0       01/04/2011
# 4           2012-01         2012-Q1        2012.0       29/08/2012
# ...             ...             ...           ...              ...
# 47753       2013-01         2013-Q1        2013.0       24/03/2014
# 47754          None            None           NaN       01/04/2012
# 47755       2012-05         2012-Q2        2012.0       01/11/2011
# 47756          None            None           NaN       21/11/2011
# 47757       1999-01         1999-Q1        1999.0       01/06/2008
#
#       last_funding_at
# 0          30/06/2012
# 1          23/09/2010
# 2          09/08/2012
# 3          01/04/2011
# 4          04/09/2014
# ...               ...
# 47753      24/03/2014
# 47754      01/04/2012
# 47755      10/09/2014
# 47756      21/11/2011
# 47757      04/04/2013
#
# [47758 rows x 18 columns]

# %% [markdown]
# ## Companies' CEOs: a Web Table
#
# Now we need to figure out who the CEOs are for corporations.  One place to look is Wikipedia, which has an HTML table describing the CEOs.
#
# https://en.wikipedia.org/wiki/List_of_chief_executive_officers#List_of_CEOs
#
# Pandas actually makes it easy to read HTML tables...

# %%
# Now let's read an HTML table!

company_ceos_df = pd.read_html('https://en.wikipedia.org/wiki/List_of_chief_executive_officers#List_of_CEOs')[0]

company_ceos_df
# Out:
#                        Company             Executive  \
# 0                    Accenture           Julie Sweet
# 1           Aditya Birla Group  Kumar Mangalam Birla
# 2                Adobe Systems      Shantanu Narayen
# 3                       Agenus         Garo H. Armen
# 4                       Airbus       Guillaume Faury
# ..                         ...                   ...
# 178                      Wipro     Thierry Delaporte
# 179                        WWE     Stephanie McMahon
# 180                Yum! Brands            Greg Creed
# 181               Zillow Group           Rich Barton
# 182  Zoom Video Communications             Eric Yuan
#
#                                                  Title    Since  \
# 0                                               CEO[1]     2019
# 1                                          Chairman[2]  1995[2]
# 2                       Chairman, president and CEO[3]     2007
# 3                            Founder, chairman, CEO[4]     1994
# 4                                               CEO[5]     2012
# ..                                                 ...      ...
# 178                                           CEO[161]     2016
# 179  Chairwoman and Co-CEO (Alongside Nick Khan) [162]     2022
# 180                                           CEO[163]     2015
# 181                                           CEO[164]     2019
# 182                   President, Chairman and CEO[165]     2011
#
#                                                                                           Notes  \
# 0                                                               Succeeded Pierre Nanterme, died
# 1                                              Part of the Birla family business house in India
# 2                                                                           Formerly with Apple
# 3                                                Founder of the Children of Armenia Fund (COAF)
# 4                                                                       Succeeded Louis Gallois
# ..                                                                                          ...
# 178                                                   Previously with Tata Consultancy Services
# 179           Chairwoman of the executive committeeChairwoman since 2022 CEO since July 22 2022
# 180                                                                Previously CEO for Taco Bell
# 181  Co-founder and previously was Zillow's CEO for nearly a decade. Succeeded Spencer Rascoff.
# 182                                 Previously corporate Vice President of engineering at Cisco
#
#         Updated
# 0    2019-01-31
# 1    2018-10-01
# 2    2018-10-01
# 3    2018-10-01
# 4    2017-11-14
# ..          ...
# 178  2017-11-11
# 179  2017-11-11
# 180  2017-11-11
# 181  2018-12-10
# 182  2020-10-12
#
# [183 rows x 6 columns]

# %% [markdown]
# ## The Problem Gets Harder... Extracting Structured Fields
#
# So far we have companies and CEOs.  But we don't have information on how old the CEOs are!
#
# For a solution, we're going to go back to Wikipedia -- this time looking at the web pages for the CEOs!
#
# This involves "crawling" the CEO pages, and "scraping" the relevant content.  In other words we have to do *information extraction*.
#
# We'll start by constructing a list of CEO web pages, from the Company CEO dataframe above.  For this, we need to take the names and do a bit of tweaking, for example adding underscores instead of spaces.

# %%
crawl_list = []

for executive in company_ceos_df['Executive']:
  crawl_list.append('https://en.wikipedia.org/wiki/' + executive.replace(' ', '_'))

crawl_list
# Out:
# ['https://en.wikipedia.org/wiki/Julie_Sweet',
#  'https://en.wikipedia.org/wiki/Kumar_Mangalam_Birla',
#  'https://en.wikipedia.org/wiki/Shantanu_Narayen',
#  'https://en.wikipedia.org/wiki/Garo_H._Armen',
#  'https://en.wikipedia.org/wiki/Guillaume_Faury',
#  'https://en.wikipedia.org/wiki/Daniel_Zhang',
#  'https://en.wikipedia.org/wiki/Andy_Jassy',
#  'https://en.wikipedia.org/wiki/Lisa_Su',
#  'https://en.wikipedia.org/wiki/Stephen_Squeri',
#  'https://en.wikipedia.org/wiki/Doug_Parker',
#  'https://en.wikipedia.org/wiki/Joseph_R._Swedish',
#  'https://en.wikipedia.org/wiki/Tim_Cook',
#  'https://en.wikipedia.org/wiki/Lakshmi_Niwas_Mittal',
#  'https://en.wikipedia.org/wiki/John_Stankey',
#  'https://en.wikipedia.org/wiki/Charles_Woodburn',
#  'https://en.wikipedia.org/wiki/Tapan_Singhel',
#  'https://en.wikipedia.org/wiki/Carlos_Torres_Vila',
#  'https://en.wikipedia.org/wiki/Brian_Moynihan',
#  'https://en.wikipedia.org/wiki/Jes_Staley',
#  'https://en.wikipedia.org/wiki/Warren_Buffett',
#  'https://en.wikipedia.org/wiki/Hubert_Joly',
#  'https://en.wikipedia.org/wiki/Sunil_Bharti_Mittal',
#  'https://en.wikipedia.org/wiki/Stephen_A._Schwarzman',
#  'https://en.wikipedia.org/wiki/Andrew_Mackenzie',
#  'https://en.wikipedia.org/wiki/Oliver_Zipse',
#  'https://en.wikipedia.org/wiki/Dave_Calhoun',
#  'https://en.wikipedia.org/wiki/Rich_Lesser',
#  'https://en.wikipedia.org/wiki/Bob_Dudley',
#  'https://en.wikipedia.org/wiki/Denise_Morrison',
#  'https://en.wikipedia.org/wiki/Mark_Shuttleworth',
#  'https://en.wikipedia.org/wiki/Aiman_Ezzat',
#  'https://en.wikipedia.org/wiki/Richard_Fairbank',
#  'https://en.wikipedia.org/wiki/Jim_Umpleby',
#  'https://en.wikipedia.org/wiki/Evan_G._Greenberg',
#  'https://en.wikipedia.org/wiki/Chuck_Robbins',
#  'https://en.wikipedia.org/wiki/Jane_Fraser',
#  'https://en.wikipedia.org/wiki/James_Quincey',
#  'https://en.wikipedia.org/wiki/Pankaj_Mittal',
#  'https://en.wikipedia.org/wiki/Brian_Humphries',
#  'https://en.wikipedia.org/wiki/Brian_L._Roberts',
#  'https://en.wikipedia.org/wiki/Tidjane_Thiam',
#  'https://en.wikipedia.org/wiki/Ola_Källenius',
#  'https://en.wikipedia.org/wiki/Michael_Dell',
#  'https://en.wikipedia.org/wiki/Ed_Bastian',
#  'https://en.wikipedia.org/wiki/Christian_Sewing',
#  'https://en.wikipedia.org/wiki/Frank_Appel',
#  'https://en.wikipedia.org/wiki/Roland_Dickey_Jr.',
#  'https://en.wikipedia.org/wiki/Edward_D._Breen',
#  'https://en.wikipedia.org/wiki/G._V._Prasad',
#  'https://en.wikipedia.org/wiki/Devin_Wenig',
#  'https://en.wikipedia.org/wiki/Andrew_Wilson',
#  'https://en.wikipedia.org/wiki/Börje_Ekholm',
#  'https://en.wikipedia.org/wiki/Darren_Woods',
#  'https://en.wikipedia.org/wiki/Lisa_S._Jones',
#  'https://en.wikipedia.org/wiki/Carmine_Di_Sibio',
#  'https://en.wikipedia.org/wiki/Mark_Zuckerberg',
#  'https://en.wikipedia.org/wiki/Frederick_W._Smith',
#  'https://en.wikipedia.org/wiki/Sergio_Marchionne',
#  'https://en.wikipedia.org/wiki/Abigail_Johnson',
#  'https://en.wikipedia.org/wiki/James_Michael_Lafferty',
#  'https://en.wikipedia.org/wiki/James_Hackett',
#  'https://en.wikipedia.org/wiki/Terry_Gou',
#  'https://en.wikipedia.org/wiki/Lachlan_Murdoch',
#  'https://en.wikipedia.org/wiki/Daymond_John',
#  'https://en.wikipedia.org/wiki/Phebe_Novakovic',
#  'https://en.wikipedia.org/wiki/H._Lawrence_Culp_Jr.',
#  'https://en.wikipedia.org/wiki/Mary_T._Barra',
#  'https://en.wikipedia.org/wiki/Emma_Walmsley',
#  'https://en.wikipedia.org/wiki/David_M._Solomon',
#  'https://en.wikipedia.org/wiki/Sundar_Pichai',
#  'https://en.wikipedia.org/wiki/Felipe_Gozon',
#  'https://en.wikipedia.org/wiki/Gunupati_Venkata_Krishna_Reddy',
#  'https://en.wikipedia.org/wiki/C_Vijayakumar',
#  'https://en.wikipedia.org/wiki/Lee_Shau_Kee',
#  'https://en.wikipedia.org/wiki/Antonio_Neri',
#  'https://en.wikipedia.org/wiki/Darius_Adamczyk',
#  'https://en.wikipedia.org/wiki/John_A._Kaneb',
#  'https://en.wikipedia.org/wiki/Noel_Quinn',
#  'https://en.wikipedia.org/wiki/Arvind_Krishna',
#  'https://en.wikipedia.org/wiki/Dikesh_Malhotra',
#  'https://en.wikipedia.org/wiki/Salil_Parekh',
#  'https://en.wikipedia.org/wiki/Pat_Gelsinger',
#  'https://en.wikipedia.org/wiki/Millard_Drexler',
#  'https://en.wikipedia.org/wiki/Richard_B._Handler',
#  'https://en.wikipedia.org/wiki/James_Dimon',
#  'https://en.wikipedia.org/wiki/Andrew_S._Rosen',
#  'https://en.wikipedia.org/wiki/Pieter_Elbers',
#  'https://en.wikipedia.org/wiki/Charles_G._Koch',
#  'https://en.wikipedia.org/wiki/Jeff_Clarke',
#  'https://en.wikipedia.org/wiki/Robert_Noel',
#  'https://en.wikipedia.org/wiki/Robert_Goldstein',
#  'https://en.wikipedia.org/wiki/Andrew_Meslow',
#  'https://en.wikipedia.org/wiki/Marillyn_Hewson',
#  'https://en.wikipedia.org/wiki/Steve_Rowe',
#  'https://en.wikipedia.org/wiki/Michael_Miebach',
#  'https://en.wikipedia.org/wiki/Chris_Kempczinski',
#  'https://en.wikipedia.org/wiki/Kevin_Sneader',
#  'https://en.wikipedia.org/wiki/Jonathan_Ornstein',
#  'https://en.wikipedia.org/wiki/Steven_A._Kandarian',
#  'https://en.wikipedia.org/wiki/Isaac_Larian',
#  'https://en.wikipedia.org/wiki/Satya_Nadella',
#  'https://en.wikipedia.org/wiki/Michael_J._Saylor',
#  'https://en.wikipedia.org/wiki/James_P._Gorman',
#  'https://en.wikipedia.org/wiki/Toxey_Haas',
#  'https://en.wikipedia.org/wiki/Chris_Beard',
#  'https://en.wikipedia.org/wiki/Vacant',
#  'https://en.wikipedia.org/wiki/Jeff_Shell',
#  'https://en.wikipedia.org/wiki/Robert_James_Thomson',
#  'https://en.wikipedia.org/wiki/Mark_Thompson',
#  'https://en.wikipedia.org/wiki/Sapnesh_Lalla',
#  'https://en.wikipedia.org/wiki/Mark_Parker',
#  'https://en.wikipedia.org/wiki/Pekka_Lundmark',
#  'https://en.wikipedia.org/wiki/Vasant_Narasimhan',
#  'https://en.wikipedia.org/wiki/Tatsumi_Kimishima',
#  'https://en.wikipedia.org/wiki/Tim_Armstrong',
#  'https://en.wikipedia.org/wiki/Safra_Catz',
#  'https://en.wikipedia.org/wiki/Mark_Hurd',
#  'https://en.wikipedia.org/wiki/Ramon_Laguarta',
#  'https://en.wikipedia.org/wiki/Albert_Bourla',
#  'https://en.wikipedia.org/wiki/Patrice_Louvet',
#  'https://en.wikipedia.org/wiki/David_S._Taylor',
#  'https://en.wikipedia.org/wiki/John_Strangfeld',
#  'https://en.wikipedia.org/wiki/Alan_Joyce',
#  'https://en.wikipedia.org/wiki/Anil_Ambani',
#  'https://en.wikipedia.org/wiki/Mukesh_Ambani',
#  'https://en.wikipedia.org/wiki/Luca_de_Meo',
#  'https://en.wikipedia.org/wiki/Phiwa_Nkambule',
#  'https://en.wikipedia.org/wiki/David_I._McKay',
#  'https://en.wikipedia.org/wiki/Ross_McEwan',
#  'https://en.wikipedia.org/wiki/Ben_van_Beurden',
#  "https://en.wikipedia.org/wiki/Michael_O'Leary",
#  'https://en.wikipedia.org/wiki/Douglas_L._Peterson',
#  'https://en.wikipedia.org/wiki/Herbert_Fisk_Johnson_III',
#  'https://en.wikipedia.org/wiki/Brian_Peddle',
#  'https://en.wikipedia.org/wiki/Oh-Hyun_Kwon',
#  'https://en.wikipedia.org/wiki/Christian_Klein',
#  'https://en.wikipedia.org/wiki/James_Goodnight',
#  'https://en.wikipedia.org/wiki/Jean-Pascal_Tricoire',
#  'https://en.wikipedia.org/wiki/Joe_Kaeser',
#  'https://en.wikipedia.org/wiki/David_Simon',
#  'https://en.wikipedia.org/wiki/Chua_Sock_Koong',
#  'https://en.wikipedia.org/wiki/Masayoshi_Son',
#  'https://en.wikipedia.org/wiki/Tony_Aquila',
#  'https://en.wikipedia.org/wiki/Gary_C._Kelly',
#  'https://en.wikipedia.org/wiki/J._Clifford_Hudson',
#  'https://en.wikipedia.org/wiki/Kevin_Johnson',
#  'https://en.wikipedia.org/wiki/Raymond_Kwok',
#  'https://en.wikipedia.org/wiki/Dilip_Shanghvi',
#  'https://en.wikipedia.org/wiki/William_H._Rogers_Jr.',
#  'https://en.wikipedia.org/wiki/Rakesh_Khanna',
#  'https://en.wikipedia.org/wiki/Brian_Cornell',
#  'https://en.wikipedia.org/wiki/Rajesh_Gopinathan',
#  'https://en.wikipedia.org/wiki/Li_Dongsheng',
#  'https://en.wikipedia.org/wiki/Andy_Penn',
#  'https://en.wikipedia.org/wiki/Ho_Ching',
#  'https://en.wikipedia.org/wiki/Dave_Lewis',
#  'https://en.wikipedia.org/wiki/Elon_Musk',
#  'https://en.wikipedia.org/wiki/Umberto_Macchi_di_Cellere',
#  'https://en.wikipedia.org/wiki/Alan_D._Schnitzer',
#  'https://en.wikipedia.org/wiki/Akio_Toyoda',
#  'https://en.wikipedia.org/wiki/Bill_Stromberg',
#  'https://en.wikipedia.org/wiki/Parag_Agrawal',
#  'https://en.wikipedia.org/wiki/Scott_Kirby',
#  'https://en.wikipedia.org/wiki/Ralph_Hamers',
#  'https://en.wikipedia.org/wiki/Joseph_C._Papa',
#  'https://en.wikipedia.org/wiki/Hans_Vestberg',
#  'https://en.wikipedia.org/wiki/Robert_Bakish',
#  'https://en.wikipedia.org/wiki/Vittorio_Colao',
#  'https://en.wikipedia.org/wiki/Herbert_Diess',
#  'https://en.wikipedia.org/wiki/Bill_Hilf',
#  'https://en.wikipedia.org/wiki/Bob_Chapek',
#  'https://en.wikipedia.org/wiki/Stefano_Pessina',
#  'https://en.wikipedia.org/wiki/Doug_McMillon',
#  'https://en.wikipedia.org/wiki/Ann_Sarnoff',
#  'https://en.wikipedia.org/wiki/Jason_Kilar',
#  'https://en.wikipedia.org/wiki/Charles_Scharf',
#  'https://en.wikipedia.org/wiki/John_Mackey',
#  'https://en.wikipedia.org/wiki/Laura_J._Alber',
#  'https://en.wikipedia.org/wiki/Thierry_Delaporte',
#  'https://en.wikipedia.org/wiki/Stephanie_McMahon',
#  'https://en.wikipedia.org/wiki/Greg_Creed',
#  'https://en.wikipedia.org/wiki/Rich_Barton',
#  'https://en.wikipedia.org/wiki/Eric_Yuan']

# %%
# Use urllib.urlopen to crawl all pages in crawl_list, and store the response of the page
# in list pages

pages = []

for url in crawl_list:
    page = url.split("/")[-1] #extract the person name at the end of the url
    print('Looking at file %s' % page)

    # An issue: some of the accent characters won't work.  We need to convert them
    # into an HTML URL.  We'll split the URL, then use "parse.quote" to change
    # the structure, then re-form the URL
    url_list = list(urllib.parse.urlsplit(url))
    url_list[2] = urllib.parse.quote(url_list[2])
    url_ascii = urllib.parse.urlunsplit(url_list)
    try:
      response = urllib.request.urlopen((url_ascii))
      #Save page and url for later use.
      pages.append(response)
    except urllib.error.URLError as e:
      print(e.reason)
# Out:
# Looking at file Julie_Sweet
# Looking at file Kumar_Mangalam_Birla
# Looking at file Shantanu_Narayen
# Looking at file Garo_H._Armen
# Looking at file Guillaume_Faury
# Looking at file Daniel_Zhang
# Looking at file Andy_Jassy
# Looking at file Lisa_Su
# Looking at file Stephen_Squeri
# Looking at file Doug_Parker
# Looking at file Joseph_R._Swedish
# Looking at file Tim_Cook
# Looking at file Lakshmi_Niwas_Mittal
# Looking at file John_Stankey
# Looking at file Charles_Woodburn
# Looking at file Tapan_Singhel
# Looking at file Carlos_Torres_Vila
# Looking at file Brian_Moynihan
# Looking at file Jes_Staley
# Looking at file Warren_Buffett
# Looking at file Hubert_Joly
# Looking at file Sunil_Bharti_Mittal
# Looking at file Stephen_A._Schwarzman
# Looking at file Andrew_Mackenzie
# Looking at file Oliver_Zipse
# Looking at file Dave_Calhoun
# Looking at file Rich_Lesser
# Looking at file Bob_Dudley
# Looking at file Denise_Morrison
# Looking at file Mark_Shuttleworth
# Looking at file Aiman_Ezzat
# Not Found
# Looking at file Richard_Fairbank
# Looking at file Jim_Umpleby
# Looking at file Evan_G._Greenberg
# Looking at file Chuck_Robbins
# Looking at file Jane_Fraser
# Looking at file James_Quincey
# Looking at file Pankaj_Mittal
# Not Found
# Looking at file Brian_Humphries
# Looking at file Brian_L._Roberts
# Looking at file Tidjane_Thiam
# Looking at file Ola_Källenius
# Looking at file Michael_Dell
# Looking at file Ed_Bastian
# Looking at file Christian_Sewing
# Looking at file Frank_Appel
# Looking at file Roland_Dickey_Jr.
# Looking at file Edward_D._Breen
# Looking at file G._V._Prasad
# Looking at file Devin_Wenig
# Looking at file Andrew_Wilson
# Looking at file Börje_Ekholm
# Looking at file Darren_Woods
# Looking at file Lisa_S._Jones
# Looking at file Carmine_Di_Sibio
# Looking at file Mark_Zuckerberg
# Looking at file Frederick_W._Smith
# Looking at file Sergio_Marchionne
# Looking at file Abigail_Johnson
# Looking at file James_Michael_Lafferty
# Looking at file James_Hackett
# Looking at file Terry_Gou
# Looking at file Lachlan_Murdoch
# Looking at file Daymond_John
# Looking at file Phebe_Novakovic
# Looking at file H._Lawrence_Culp_Jr.
# Looking at file Mary_T._Barra
# Looking at file Emma_Walmsley
# Looking at file David_M._Solomon
# Looking at file Sundar_Pichai
# Looking at file Felipe_Gozon
# Looking at file Gunupati_Venkata_Krishna_Reddy
# Looking at file C_Vijayakumar
# Looking at file Lee_Shau_Kee
# Looking at file Antonio_Neri
# Looking at file Darius_Adamczyk
# Looking at file John_A._Kaneb
# Looking at file Noel_Quinn
# Looking at file Arvind_Krishna
# Looking at file Dikesh_Malhotra
# Looking at file Salil_Parekh
# Looking at file Pat_Gelsinger
# Looking at file Millard_Drexler
# Looking at file Richard_B._Handler
# Looking at file James_Dimon
# Looking at file Andrew_S._Rosen
# Looking at file Pieter_Elbers
# Looking at file Charles_G._Koch
# Looking at file Jeff_Clarke
# Looking at file Robert_Noel
# Looking at file Robert_Goldstein
# Looking at file Andrew_Meslow
# Not Found
# Looking at file Marillyn_Hewson
# Looking at file Steve_Rowe
# Looking at file Michael_Miebach
# Not Found
# Looking at file Chris_Kempczinski
# Looking at file Kevin_Sneader
# Looking at file Jonathan_Ornstein
# Looking at file Steven_A._Kandarian
# Looking at file Isaac_Larian
# Looking at file Satya_Nadella
# Looking at file Michael_J._Saylor
# Looking at file James_P._Gorman
# Looking at file Toxey_Haas
# Looking at file Chris_Beard
# Looking at file Vacant
# Looking at file Jeff_Shell
# Looking at file Robert_James_Thomson
# Looking at file Mark_Thompson
# Looking at file Sapnesh_Lalla
# Not Found
# Looking at file Mark_Parker
# Looking at file Pekka_Lundmark
# Looking at file Vasant_Narasimhan
# Looking at file Tatsumi_Kimishima
# Looking at file Tim_Armstrong
# Looking at file Safra_Catz
# Looking at file Mark_Hurd
# Looking at file Ramon_Laguarta
# Looking at file Albert_Bourla
# Looking at file Patrice_Louvet
# Looking at file David_S._Taylor
# Looking at file John_Strangfeld
# Looking at file Alan_Joyce
# Looking at file Anil_Ambani
# Looking at file Mukesh_Ambani
# Looking at file Luca_de_Meo
# Looking at file Phiwa_Nkambule
# Looking at file David_I._McKay
# Looking at file Ross_McEwan
# Looking at file Ben_van_Beurden
# Looking at file Michael_O'Leary
# Looking at file Douglas_L._Peterson
# Looking at file Herbert_Fisk_Johnson_III
# Looking at file Brian_Peddle
# Looking at file Oh-Hyun_Kwon
# Looking at file Christian_Klein
# Looking at file James_Goodnight
# Looking at file Jean-Pascal_Tricoire
# Looking at file Joe_Kaeser
# Looking at file David_Simon
# Looking at file Chua_Sock_Koong
# Looking at file Masayoshi_Son
# Looking at file Tony_Aquila
# Looking at file Gary_C._Kelly
# Looking at file J._Clifford_Hudson
# Looking at file Kevin_Johnson
# Looking at file Raymond_Kwok
# Looking at file Dilip_Shanghvi
# Looking at file William_H._Rogers_Jr.
# Looking at file Rakesh_Khanna
# Looking at file Brian_Cornell
# Looking at file Rajesh_Gopinathan
# Looking at file Li_Dongsheng
# Looking at file Andy_Penn
# Looking at file Ho_Ching
# Looking at file Dave_Lewis
# Looking at file Elon_Musk
# Looking at file Umberto_Macchi_di_Cellere
# Not Found
# Looking at file Alan_D._Schnitzer
# Looking at file Akio_Toyoda
# Looking at file Bill_Stromberg
# Looking at file Parag_Agrawal
# Looking at file Scott_Kirby
# Looking at file Ralph_Hamers
# Looking at file Joseph_C._Papa
# Looking at file Hans_Vestberg
# Looking at file Robert_Bakish
# Looking at file Vittorio_Colao
# Looking at file Herbert_Diess
# Looking at file Bill_Hilf
# Looking at file Bob_Chapek
# Looking at file Stefano_Pessina
# Looking at file Doug_McMillon
# Looking at file Ann_Sarnoff
# Looking at file Jason_Kilar
# Looking at file Charles_Scharf
# Looking at file John_Mackey
# Looking at file Laura_J._Alber
# Looking at file Thierry_Delaporte
# Not Found
# Looking at file Stephanie_McMahon
# Looking at file Greg_Creed
# Looking at file Rich_Barton
# Looking at file Eric_Yuan

# %%
pages
# Out:
# [<http.client.HTTPResponse at 0x7f714a57e710>,
#  <http.client.HTTPResponse at 0x7f714a57ec90>,
#  <http.client.HTTPResponse at 0x7f7151ca0990>,
#  <http.client.HTTPResponse at 0x7f714a57e050>,
#  <http.client.HTTPResponse at 0x7f714a569f50>,
#  <http.client.HTTPResponse at 0x7f714a57ec10>,
#  <http.client.HTTPResponse at 0x7f7151f22c90>,
#  <http.client.HTTPResponse at 0x7f7151cf1810>,
#  <http.client.HTTPResponse at 0x7f714a57e890>,
#  <http.client.HTTPResponse at 0x7f714affbc10>,
#  <http.client.HTTPResponse at 0x7f7151cce690>,
#  <http.client.HTTPResponse at 0x7f714a57ea10>,
#  <http.client.HTTPResponse at 0x7f714aff69d0>,
#  <http.client.HTTPResponse at 0x7f714aff6790>,
#  <http.client.HTTPResponse at 0x7f71501a38d0>,
#  <http.client.HTTPResponse at 0x7f71479f5410>,
#  <http.client.HTTPResponse at 0x7f71479f5510>,
#  <http.client.HTTPResponse at 0x7f7148137490>,
#  <http.client.HTTPResponse at 0x7f714a57e510>,
#  <http.client.HTTPResponse at 0x7f714aff6b90>,
#  <http.client.HTTPResponse at 0x7f714b8737d0>,
#  <http.client.HTTPResponse at 0x7f714a57e8d0>,
#  <http.client.HTTPResponse at 0x7f7147d06790>,
#  <http.client.HTTPResponse at 0x7f7147b9d810>,
#  <http.client.HTTPResponse at 0x7f7147bac950>,
#  <http.client.HTTPResponse at 0x7f7151d1f3d0>,
#  <http.client.HTTPResponse at 0x7f714a57e0d0>,
#  <http.client.HTTPResponse at 0x7f714b0c6b50>,
#  <http.client.HTTPResponse at 0x7f7147ce7e90>,
#  <http.client.HTTPResponse at 0x7f7147878d90>,
#  <http.client.HTTPResponse at 0x7f714a57e950>,
#  <http.client.HTTPResponse at 0x7f714adff7d0>,
#  <http.client.HTTPResponse at 0x7f714ad50a50>,
#  <http.client.HTTPResponse at 0x7f714ad50b50>,
#  <http.client.HTTPResponse at 0x7f7148137590>,
#  <http.client.HTTPResponse at 0x7f714adff1d0>,
#  <http.client.HTTPResponse at 0x7f714ad843d0>,
#  <http.client.HTTPResponse at 0x7f714ad84450>,
#  <http.client.HTTPResponse at 0x7f714ad8fed0>,
#  <http.client.HTTPResponse at 0x7f714ad8f550>,
#  <http.client.HTTPResponse at 0x7f714a9a4690>,
#  <http.client.HTTPResponse at 0x7f714a9a4f90>,
#  <http.client.HTTPResponse at 0x7f714ad8f510>,
#  <http.client.HTTPResponse at 0x7f714a57eb50>,
#  <http.client.HTTPResponse at 0x7f714ad84cd0>,
#  <http.client.HTTPResponse at 0x7f714affbc90>,
#  <http.client.HTTPResponse at 0x7f714ad60250>,
#  <http.client.HTTPResponse at 0x7f714a8e4f50>,
#  <http.client.HTTPResponse at 0x7f7151d1af90>,
#  <http.client.HTTPResponse at 0x7f714a8fbf50>,
#  <http.client.HTTPResponse at 0x7f714a755190>,
#  <http.client.HTTPResponse at 0x7f714a770050>,
#  <http.client.HTTPResponse at 0x7f714ade5f90>,
#  <http.client.HTTPResponse at 0x7f714a780190>,
#  <http.client.HTTPResponse at 0x7f714a780ad0>,
#  <http.client.HTTPResponse at 0x7f714a780b10>,
#  <http.client.HTTPResponse at 0x7f714a8fb690>,
#  <http.client.HTTPResponse at 0x7f714a789e50>,
#  <http.client.HTTPResponse at 0x7f714a8fbed0>,
#  <http.client.HTTPResponse at 0x7f714a6e96d0>,
#  <http.client.HTTPResponse at 0x7f714a70e990>,
#  <http.client.HTTPResponse at 0x7f714a8e4710>,
#  <http.client.HTTPResponse at 0x7f714ad60b10>,
#  <http.client.HTTPResponse at 0x7f7147d060d0>,
#  <http.client.HTTPResponse at 0x7f714a4e7050>,
#  <http.client.HTTPResponse at 0x7f714a6fc690>,
#  <http.client.HTTPResponse at 0x7f714a789390>,
#  <http.client.HTTPResponse at 0x7f714a9a4ed0>,
#  <http.client.HTTPResponse at 0x7f714a3956d0>,
#  <http.client.HTTPResponse at 0x7f714a395f50>,
#  <http.client.HTTPResponse at 0x7f714a770890>,
#  <http.client.HTTPResponse at 0x7f714a3b90d0>,
#  <http.client.HTTPResponse at 0x7f714a356990>,
#  <http.client.HTTPResponse at 0x7f714a3a7790>,
#  <http.client.HTTPResponse at 0x7f714a3a7fd0>,
#  <http.client.HTTPResponse at 0x7f714a3955d0>,
#  <http.client.HTTPResponse at 0x7f714a3b9b10>,
#  <http.client.HTTPResponse at 0x7f714a385310>,
#  <http.client.HTTPResponse at 0x7f714a356290>,
#  <http.client.HTTPResponse at 0x7f714a25cd50>,
#  <http.client.HTTPResponse at 0x7f714a395610>,
#  <http.client.HTTPResponse at 0x7f714a755810>,
#  <http.client.HTTPResponse at 0x7f714a25c510>,
#  <http.client.HTTPResponse at 0x7f714a36b290>,
#  <http.client.HTTPResponse at 0x7f714a36bad0>,
#  <http.client.HTTPResponse at 0x7f7149f95c10>,
#  <http.client.HTTPResponse at 0x7f7149f95cd0>,
#  <http.client.HTTPResponse at 0x7f714a356910>,
#  <http.client.HTTPResponse at 0x7f7147878890>,
#  <http.client.HTTPResponse at 0x7f7149e24fd0>,
#  <http.client.HTTPResponse at 0x7f714a276ed0>,
#  <http.client.HTTPResponse at 0x7f7149e24790>,
#  <http.client.HTTPResponse at 0x7f7149e24150>,
#  <http.client.HTTPResponse at 0x7f714adff810>,
#  <http.client.HTTPResponse at 0x7f7149e46f90>,
#  <http.client.HTTPResponse at 0x7f7149d9c310>,
#  <http.client.HTTPResponse at 0x7f7149fc56d0>,
#  <http.client.HTTPResponse at 0x7f7149e46ad0>,
#  <http.client.HTTPResponse at 0x7f7149dbe4d0>,
#  <http.client.HTTPResponse at 0x7f714a6fc5d0>,
#  <http.client.HTTPResponse at 0x7f714a36b210>,
#  <http.client.HTTPResponse at 0x7f7149e24750>,
#  <http.client.HTTPResponse at 0x7f7149d9cdd0>,
#  <http.client.HTTPResponse at 0x7f714a25cd10>,
#  <http.client.HTTPResponse at 0x7f7149be46d0>,
#  <http.client.HTTPResponse at 0x7f7149dc9790>,
#  <http.client.HTTPResponse at 0x7f7149c09d10>,
#  <http.client.HTTPResponse at 0x7f7149b2cfd0>,
#  <http.client.HTTPResponse at 0x7f7149b2c5d0>,
#  <http.client.HTTPResponse at 0x7f7149bff350>,
#  <http.client.HTTPResponse at 0x7f7149b48810>,
#  <http.client.HTTPResponse at 0x7f7149927110>,
#  <http.client.HTTPResponse at 0x7f7149bffd50>,
#  <http.client.HTTPResponse at 0x7f71499279d0>,
#  <http.client.HTTPResponse at 0x7f714994a2d0>,
#  <http.client.HTTPResponse at 0x7f714994a350>,
#  <http.client.HTTPResponse at 0x7f7149bffc90>,
#  <http.client.HTTPResponse at 0x7f7149897c50>,
#  <http.client.HTTPResponse at 0x7f7149b487d0>,
#  <http.client.HTTPResponse at 0x7f7149b48710>,
#  <http.client.HTTPResponse at 0x7f714991ba90>,
#  <http.client.HTTPResponse at 0x7f7149897ed0>,
#  <http.client.HTTPResponse at 0x7f714994ad90>,
#  <http.client.HTTPResponse at 0x7f7149927c50>,
#  <http.client.HTTPResponse at 0x7f71494e1c10>,
#  <http.client.HTTPResponse at 0x7f71494e1510>,
#  <http.client.HTTPResponse at 0x7f71494fd5d0>,
#  <http.client.HTTPResponse at 0x7f71494f3410>,
#  <http.client.HTTPResponse at 0x7f71494f3c90>,
#  <http.client.HTTPResponse at 0x7f71494f3690>,
#  <http.client.HTTPResponse at 0x7f7149477c90>,
#  <http.client.HTTPResponse at 0x7f71493ab050>,
#  <http.client.HTTPResponse at 0x7f7149477190>,
#  <http.client.HTTPResponse at 0x7f71493bd210>,
#  <http.client.HTTPResponse at 0x7f7149fc5f10>,
#  <http.client.HTTPResponse at 0x7f71494e1bd0>,
#  <http.client.HTTPResponse at 0x7f71493cdb90>,
#  <http.client.HTTPResponse at 0x7f714a789410>,
#  <http.client.HTTPResponse at 0x7f7149477990>,
#  <http.client.HTTPResponse at 0x7f714950f750>,
#  <http.client.HTTPResponse at 0x7f71493bd450>,
#  <http.client.HTTPResponse at 0x7f7149927190>,
#  <http.client.HTTPResponse at 0x7f714938aad0>,
#  <http.client.HTTPResponse at 0x7f71493bda50>,
#  <http.client.HTTPResponse at 0x7f71494e1350>,
#  <http.client.HTTPResponse at 0x7f7149321c50>,
#  <http.client.HTTPResponse at 0x7f71493324d0>,
#  <http.client.HTTPResponse at 0x7f714934ad90>,
#  <http.client.HTTPResponse at 0x7f714934ae50>,
#  <http.client.HTTPResponse at 0x7f714938a210>,
#  <http.client.HTTPResponse at 0x7f714934add0>,
#  <http.client.HTTPResponse at 0x7f7149321350>,
#  <http.client.HTTPResponse at 0x7f71490f0890>,
#  <http.client.HTTPResponse at 0x7f7148f9c250>,
#  <http.client.HTTPResponse at 0x7f7149321390>,
#  <http.client.HTTPResponse at 0x7f7148f9c1d0>,
#  <http.client.HTTPResponse at 0x7f71493bdb10>,
#  <http.client.HTTPResponse at 0x7f71490f0910>,
#  <http.client.HTTPResponse at 0x7f71490f0850>,
#  <http.client.HTTPResponse at 0x7f7148fc0410>,
#  <http.client.HTTPResponse at 0x7f7148f9c190>,
#  <http.client.HTTPResponse at 0x7f71490def90>,
#  <http.client.HTTPResponse at 0x7f7149482a50>,
#  <http.client.HTTPResponse at 0x7f7148d9cbd0>,
#  <http.client.HTTPResponse at 0x7f7149482350>,
#  <http.client.HTTPResponse at 0x7f7148db1e10>,
#  <http.client.HTTPResponse at 0x7f71490deed0>,
#  <http.client.HTTPResponse at 0x7f7149332f10>,
#  <http.client.HTTPResponse at 0x7f7148d9c2d0>,
#  <http.client.HTTPResponse at 0x7f7148d5bf50>,
#  <http.client.HTTPResponse at 0x7f7148d62790>,
#  <http.client.HTTPResponse at 0x7f7148d84050>,
#  <http.client.HTTPResponse at 0x7f7148d84290>,
#  <http.client.HTTPResponse at 0x7f714950f650>,
#  <http.client.HTTPResponse at 0x7f7148ca4250>,
#  <http.client.HTTPResponse at 0x7f7148d84950>]

# %% [markdown]
# ## Populating the Table with Executives

# %%
# Use lxml.etree.HTML(...) on the HTML content of each page to get a DOM tree that
# can be processed via XPath to extract the bday information.  Store the CEO name,
# webpage, and the birthdate (born) in exec_df.

# We first check that the HTML content has a table of type `vcard`,
# and then extract the `bday` information.  If there is no birthdate, the datetime
# value is NaT (not a type).

from lxml import etree

exec_df = pd.DataFrame(columns=['name','page','born'])

for page in pages:
    tree = etree.HTML(page.read().decode("utf-8"))  #create a DOM tree of the page
    url = page.geturl()
    bday = tree.xpath('//table[contains(@class,"vcard")]//span[@class="bday"]/text()')
    if len(bday) > 0:
        name = url[url.rfind('/')+1:] # The part of the URL after the last /
        exec_df = exec_df.append({'name': name, 'page': url,
                   'born': datetime.datetime.strptime(bday[0], '%Y-%m-%d')}, ignore_index=True)
    else:
            exec_df = exec_df.append({'name': url[url.rfind('/')+1:], 'page': url
                                      , 'born': np.datetime64('NaT')}, ignore_index=True)

exec_df
# Out:
#                      name                                                page  \
# 0             Julie_Sweet           https://en.wikipedia.org/wiki/Julie_Sweet
# 1    Kumar_Mangalam_Birla  https://en.wikipedia.org/wiki/Kumar_Mangalam_Birla
# 2        Shantanu_Narayen      https://en.wikipedia.org/wiki/Shantanu_Narayen
# 3           Garo_H._Armen         https://en.wikipedia.org/wiki/Garo_H._Armen
# 4         Guillaume_Faury       https://en.wikipedia.org/wiki/Guillaume_Faury
# ..                    ...                                                 ...
# 171        Laura_J._Alber        https://en.wikipedia.org/wiki/Laura_J._Alber
# 172     Stephanie_McMahon     https://en.wikipedia.org/wiki/Stephanie_McMahon
# 173            Greg_Creed            https://en.wikipedia.org/wiki/Greg_Creed
# 174           Rich_Barton           https://en.wikipedia.org/wiki/Rich_Barton
# 175             Eric_Yuan             https://en.wikipedia.org/wiki/Eric_Yuan
#
#                     born
# 0                    NaT
# 1    1967-06-14 00:00:00
# 2    1963-05-27 00:00:00
# 3    1953-01-31 00:00:00
# 4    1968-02-22 00:00:00
# ..                   ...
# 171                  NaN
# 172  1976-09-24 00:00:00
# 173                  NaN
# 174                  NaN
# 175  1970-02-20 00:00:00
#
# [176 rows x 3 columns]

# %% [markdown]
# # Lecture Module 2: Data Transformation
#
# Looking at our data to clean via *projection*...
#
# Generally, we can extract one "narrower" table form another by using **double brackets**.

# %%
# Let's take a look at the data.  Here's a way of PROJECTING the exec_df dataframe into
# a smaller table

exec_df[['name', 'born']]
# Out:
#                      name                 born
# 0             Julie_Sweet                  NaT
# 1    Kumar_Mangalam_Birla  1967-06-14 00:00:00
# 2        Shantanu_Narayen  1963-05-27 00:00:00
# 3           Garo_H._Armen  1953-01-31 00:00:00
# 4         Guillaume_Faury  1968-02-22 00:00:00
# ..                    ...                  ...
# 171        Laura_J._Alber                  NaN
# 172     Stephanie_McMahon  1976-09-24 00:00:00
# 173            Greg_Creed                  NaN
# 174           Rich_Barton                  NaN
# 175             Eric_Yuan  1970-02-20 00:00:00
#
# [176 rows x 2 columns]

# %%
# If I use single brackets, I can extract a single column as a Series.
exec_df['name']
# Out:
# 0               Julie_Sweet
# 1      Kumar_Mangalam_Birla
# 2          Shantanu_Narayen
# 3             Garo_H._Armen
# 4           Guillaume_Faury
#                ...
# 171          Laura_J._Alber
# 172       Stephanie_McMahon
# 173              Greg_Creed
# 174             Rich_Barton
# 175               Eric_Yuan
# Name: name, Length: 176, dtype: object

# %%
# Notice anything awry?

for person in exec_df['name']:
    print (person)
# Out:
# Julie_Sweet
# Kumar_Mangalam_Birla
# Shantanu_Narayen
# Garo_H._Armen
# Guillaume_Faury
# Daniel_Zhang
# Andy_Jassy
# Lisa_Su
# Stephen_Squeri
# Doug_Parker
# Joseph_R._Swedish
# Tim_Cook
# Lakshmi_Niwas_Mittal
# John_Stankey
# Charles_Woodburn
# Tapan_Singhel
# Carlos_Torres_Vila
# Brian_Moynihan
# Jes_Staley
# Warren_Buffett
# Hubert_Joly
# Sunil_Bharti_Mittal
# Stephen_A._Schwarzman
# Andrew_Mackenzie
# Oliver_Zipse
# Dave_Calhoun
# Rich_Lesser
# Bob_Dudley
# Denise_Morrison
# Mark_Shuttleworth
# Richard_Fairbank
# Jim_Umpleby
# Evan_G._Greenberg
# Chuck_Robbins
# Jane_Fraser
# James_Quincey
# Brian_Humphries
# Brian_L._Roberts
# Tidjane_Thiam
# Ola_K%C3%A4llenius
# Michael_Dell
# Ed_Bastian
# Christian_Sewing
# Frank_Appel
# Roland_Dickey_Jr.
# Edward_D._Breen
# G._V._Prasad
# Devin_Wenig
# Andrew_Wilson
# B%C3%B6rje_Ekholm
# Darren_Woods
# Lisa_S._Jones
# Carmine_Di_Sibio
# Mark_Zuckerberg
# Frederick_W._Smith
# Sergio_Marchionne
# Abigail_Johnson
# James_Michael_Lafferty
# James_Hackett
# Terry_Gou
# Lachlan_Murdoch
# Daymond_John
# Phebe_Novakovic
# H._Lawrence_Culp_Jr.
# Mary_T._Barra
# Emma_Walmsley
# David_M._Solomon
# Sundar_Pichai
# Felipe_Gozon
# Gunupati_Venkata_Krishna_Reddy
# C_Vijayakumar
# Lee_Shau_Kee
# Antonio_Neri
# Darius_Adamczyk
# John_A._Kaneb
# Noel_Quinn
# Arvind_Krishna
# Dikesh_Malhotra
# Salil_Parekh
# Pat_Gelsinger
# Millard_Drexler
# Richard_B._Handler
# James_Dimon
# Andrew_S._Rosen
# Pieter_Elbers
# Charles_G._Koch
# Jeff_Clarke
# Robert_Noel
# Robert_Goldstein
# Marillyn_Hewson
# Steve_Rowe
# Chris_Kempczinski
# Kevin_Sneader
# Jonathan_Ornstein
# Steven_A._Kandarian
# Isaac_Larian
# Satya_Nadella
# Michael_J._Saylor
# James_P._Gorman
# Toxey_Haas
# Chris_Beard
# Vacant
# Jeff_Shell
# Robert_James_Thomson
# Mark_Thompson
# Mark_Parker
# Pekka_Lundmark
# Vasant_Narasimhan
# Tatsumi_Kimishima
# Tim_Armstrong
# Safra_Catz
# Mark_Hurd
# Ramon_Laguarta
# Albert_Bourla
# Patrice_Louvet
# David_S._Taylor
# John_Strangfeld
# Alan_Joyce
# Anil_Ambani
# Mukesh_Ambani
# Luca_de_Meo
# Phiwa_Nkambule
# David_I._McKay
# Ross_McEwan
# Ben_van_Beurden
# Michael_O%27Leary
# Douglas_L._Peterson
# Herbert_Fisk_Johnson_III
# Brian_Peddle
# Oh-Hyun_Kwon
# Christian_Klein
# James_Goodnight
# Jean-Pascal_Tricoire
# Joe_Kaeser
# David_Simon
# Chua_Sock_Koong
# Masayoshi_Son
# Tony_Aquila
# Gary_C._Kelly
# J._Clifford_Hudson
# Kevin_Johnson
# Raymond_Kwok
# Dilip_Shanghvi
# William_H._Rogers_Jr.
# Rakesh_Khanna
# Brian_Cornell
# Rajesh_Gopinathan
# Li_Dongsheng
# Andy_Penn
# Ho_Ching
# Dave_Lewis
# Elon_Musk
# Alan_D._Schnitzer
# Akio_Toyoda
# Bill_Stromberg
# Parag_Agrawal
# Scott_Kirby
# Ralph_Hamers
# Joseph_C._Papa
# Hans_Vestberg
# Robert_Bakish
# Vittorio_Colao
# Herbert_Diess
# Bill_Hilf
# Bob_Chapek
# Stefano_Pessina
# Doug_McMillon
# Ann_Sarnoff
# Jason_Kilar
# Charles_Scharf
# John_Mackey
# Laura_J._Alber
# Stephanie_McMahon
# Greg_Creed
# Rich_Barton
# Eric_Yuan

# %%
def to_space(x):
  return x.replace('_', ' ')

# Let's use *apply* to call a function over each element, returning a new Series
exec_df['name'].apply(to_space)
# Out:
# 0               Julie Sweet
# 1      Kumar Mangalam Birla
# 2          Shantanu Narayen
# 3             Garo H. Armen
# 4           Guillaume Faury
#                ...
# 171          Laura J. Alber
# 172       Stephanie McMahon
# 173              Greg Creed
# 174             Rich Barton
# 175               Eric Yuan
# Name: name, Length: 176, dtype: object

# %%
# Let's use *apply* to call a function over each element, returning a new Series
exec_df['name'].apply(lambda x: x.replace('_', ' '))
# Out:
# 0               Julie Sweet
# 1      Kumar Mangalam Birla
# 2          Shantanu Narayen
# 3             Garo H. Armen
# 4           Guillaume Faury
#                ...
# 171          Laura J. Alber
# 172       Stephanie McMahon
# 173              Greg Creed
# 174             Rich Barton
# 175               Eric Yuan
# Name: name, Length: 176, dtype: object

# %%
# I can also use *apply* to call a function over the rows of a dataframe
exec_df.apply(lambda x: x['name'].replace('_', ' '), axis=1)
# Out:
# 0               Julie Sweet
# 1      Kumar Mangalam Birla
# 2          Shantanu Narayen
# 3             Garo H. Armen
# 4           Guillaume Faury
#                ...
# 171          Laura J. Alber
# 172       Stephanie McMahon
# 173              Greg Creed
# 174             Rich Barton
# 175               Eric Yuan
# Length: 176, dtype: object

# %%
# Let's clean the name by removing underscores...
exec_df['clean_name'] = exec_df['name'].apply(lambda x: x.replace('_', ' '))

exec_df
# Out:
#                      name                                                page  \
# 0             Julie_Sweet           https://en.wikipedia.org/wiki/Julie_Sweet
# 1    Kumar_Mangalam_Birla  https://en.wikipedia.org/wiki/Kumar_Mangalam_Birla
# 2        Shantanu_Narayen      https://en.wikipedia.org/wiki/Shantanu_Narayen
# 3           Garo_H._Armen         https://en.wikipedia.org/wiki/Garo_H._Armen
# 4         Guillaume_Faury       https://en.wikipedia.org/wiki/Guillaume_Faury
# ..                    ...                                                 ...
# 171        Laura_J._Alber        https://en.wikipedia.org/wiki/Laura_J._Alber
# 172     Stephanie_McMahon     https://en.wikipedia.org/wiki/Stephanie_McMahon
# 173            Greg_Creed            https://en.wikipedia.org/wiki/Greg_Creed
# 174           Rich_Barton           https://en.wikipedia.org/wiki/Rich_Barton
# 175             Eric_Yuan             https://en.wikipedia.org/wiki/Eric_Yuan
#
#                     born            clean_name
# 0                    NaT           Julie Sweet
# 1    1967-06-14 00:00:00  Kumar Mangalam Birla
# 2    1963-05-27 00:00:00      Shantanu Narayen
# 3    1953-01-31 00:00:00         Garo H. Armen
# 4    1968-02-22 00:00:00       Guillaume Faury
# ..                   ...                   ...
# 171                  NaN        Laura J. Alber
# 172  1976-09-24 00:00:00     Stephanie McMahon
# 173                  NaN            Greg Creed
# 174                  NaN           Rich Barton
# 175  1970-02-20 00:00:00             Eric Yuan
#
# [176 rows x 4 columns]

# %%
exec_df.rename(columns={'name': 'old_name'})
# Out:
#                  old_name                                                page  \
# 0             Julie_Sweet           https://en.wikipedia.org/wiki/Julie_Sweet
# 1    Kumar_Mangalam_Birla  https://en.wikipedia.org/wiki/Kumar_Mangalam_Birla
# 2        Shantanu_Narayen      https://en.wikipedia.org/wiki/Shantanu_Narayen
# 3           Garo_H._Armen         https://en.wikipedia.org/wiki/Garo_H._Armen
# 4         Guillaume_Faury       https://en.wikipedia.org/wiki/Guillaume_Faury
# ..                    ...                                                 ...
# 171        Laura_J._Alber        https://en.wikipedia.org/wiki/Laura_J._Alber
# 172     Stephanie_McMahon     https://en.wikipedia.org/wiki/Stephanie_McMahon
# 173            Greg_Creed            https://en.wikipedia.org/wiki/Greg_Creed
# 174           Rich_Barton           https://en.wikipedia.org/wiki/Rich_Barton
# 175             Eric_Yuan             https://en.wikipedia.org/wiki/Eric_Yuan
#
#                     born            clean_name
# 0                    NaT           Julie Sweet
# 1    1967-06-14 00:00:00  Kumar Mangalam Birla
# 2    1963-05-27 00:00:00      Shantanu Narayen
# 3    1953-01-31 00:00:00         Garo H. Armen
# 4    1968-02-22 00:00:00       Guillaume Faury
# ..                   ...                   ...
# 171                  NaN        Laura J. Alber
# 172  1976-09-24 00:00:00     Stephanie McMahon
# 173                  NaN            Greg Creed
# 174                  NaN           Rich Barton
# 175  1970-02-20 00:00:00             Eric Yuan
#
# [176 rows x 4 columns]

# %%
# We can do the same via SQL.  For the example we'll save the dataframe first...  we'll convert
# types to string first to avoid errors.

temp_df= exec_df.applymap(str)
temp_df.to_sql('temp_exec', conn, if_exists="replace")

pd.read_sql_query('select name, replace(name, "_", " ") as clean_name from temp_exec', conn)
# Out:
#                      name            clean_name
# 0             Julie_Sweet           Julie Sweet
# 1    Kumar_Mangalam_Birla  Kumar Mangalam Birla
# 2        Shantanu_Narayen      Shantanu Narayen
# 3           Garo_H._Armen         Garo H. Armen
# 4         Guillaume_Faury       Guillaume Faury
# ..                    ...                   ...
# 171        Laura_J._Alber        Laura J. Alber
# 172     Stephanie_McMahon     Stephanie McMahon
# 173            Greg_Creed            Greg Creed
# 174           Rich_Barton           Rich Barton
# 175             Eric_Yuan             Eric Yuan
#
# [176 rows x 2 columns]

# %% [markdown]
# ## Selecting a subset of the rows

# %%
# Here's a column

exec_df['clean_name']
# Out:
# 0               Julie Sweet
# 1      Kumar Mangalam Birla
# 2          Shantanu Narayen
# 3             Garo H. Armen
# 4           Guillaume Faury
#                ...
# 171          Laura J. Alber
# 172       Stephanie McMahon
# 173              Greg Creed
# 174             Rich Barton
# 175               Eric Yuan
# Name: clean_name, Length: 176, dtype: object

# %%
# We can apply a test (predicate) to each column, returning a Series of boolean true/false values

exec_df['clean_name'] == 'Julie Sweet'
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 171    False
# 172    False
# 173    False
# 174    False
# 175    False
# Name: clean_name, Length: 176, dtype: bool

# %%
# If we compose these, we'll get only those rows where the boolean condition was True

exec_df[exec_df['clean_name'] == 'Julie Sweet']
# Out:
#           name                                       page born   clean_name
# 0  Julie_Sweet  https://en.wikipedia.org/wiki/Julie_Sweet  NaT  Julie Sweet

# %%
exec_df[exec_df['clean_name'] == 'Julie Sweet'][['page']]
# Out:
#                                         page
# 0  https://en.wikipedia.org/wiki/Julie_Sweet

# %%
# And in SQL...

temp_df= exec_df.applymap(str)
temp_df.to_sql('temp_exec', conn, if_exists="replace")

pd.read_sql_query('select * from temp_exec where clean_name="Julie Sweet"', conn)
# Out:
#    index         name                                       page born  \
# 0      0  Julie_Sweet  https://en.wikipedia.org/wiki/Julie_Sweet  NaT
#
#     clean_name
# 0  Julie Sweet

# %%
pd.read_sql_query('select page from temp_exec where clean_name="Julie Sweet"', conn)
# Out:
#                                         page
# 0  https://en.wikipedia.org/wiki/Julie_Sweet

# %%
import numpy as np

exec_df.dropna(subset=['born'])
# Out:
#                      name                                                page  \
# 1    Kumar_Mangalam_Birla  https://en.wikipedia.org/wiki/Kumar_Mangalam_Birla
# 2        Shantanu_Narayen      https://en.wikipedia.org/wiki/Shantanu_Narayen
# 3           Garo_H._Armen         https://en.wikipedia.org/wiki/Garo_H._Armen
# 4         Guillaume_Faury       https://en.wikipedia.org/wiki/Guillaume_Faury
# 5            Daniel_Zhang          https://en.wikipedia.org/wiki/Daniel_Zhang
# ..                    ...                                                 ...
# 166         Doug_McMillon         https://en.wikipedia.org/wiki/Doug_McMillon
# 168           Jason_Kilar           https://en.wikipedia.org/wiki/Jason_Kilar
# 169        Charles_Scharf        https://en.wikipedia.org/wiki/Charles_Scharf
# 172     Stephanie_McMahon     https://en.wikipedia.org/wiki/Stephanie_McMahon
# 175             Eric_Yuan             https://en.wikipedia.org/wiki/Eric_Yuan
#
#                     born            clean_name
# 1    1967-06-14 00:00:00  Kumar Mangalam Birla
# 2    1963-05-27 00:00:00      Shantanu Narayen
# 3    1953-01-31 00:00:00         Garo H. Armen
# 4    1968-02-22 00:00:00       Guillaume Faury
# 5    1972-01-11 00:00:00          Daniel Zhang
# ..                   ...                   ...
# 166  1966-10-17 00:00:00         Doug McMillon
# 168  1971-04-26 00:00:00           Jason Kilar
# 169  1965-04-24 00:00:00        Charles Scharf
# 172  1976-09-24 00:00:00     Stephanie McMahon
# 175  1970-02-20 00:00:00             Eric Yuan
#
# [105 rows x 4 columns]

# %%
pd.read_sql_query('select * from temp_exec where born is not null', conn).set_index('index')
# Out:
#                        name  \
# index
# 0               Julie_Sweet
# 1      Kumar_Mangalam_Birla
# 2          Shantanu_Narayen
# 3             Garo_H._Armen
# 4           Guillaume_Faury
# ...                     ...
# 171          Laura_J._Alber
# 172       Stephanie_McMahon
# 173              Greg_Creed
# 174             Rich_Barton
# 175               Eric_Yuan
#
#                                                      page  \
# index
# 0               https://en.wikipedia.org/wiki/Julie_Sweet
# 1      https://en.wikipedia.org/wiki/Kumar_Mangalam_Birla
# 2          https://en.wikipedia.org/wiki/Shantanu_Narayen
# 3             https://en.wikipedia.org/wiki/Garo_H._Armen
# 4           https://en.wikipedia.org/wiki/Guillaume_Faury
# ...                                                   ...
# 171          https://en.wikipedia.org/wiki/Laura_J._Alber
# 172       https://en.wikipedia.org/wiki/Stephanie_McMahon
# 173              https://en.wikipedia.org/wiki/Greg_Creed
# 174             https://en.wikipedia.org/wiki/Rich_Barton
# 175               https://en.wikipedia.org/wiki/Eric_Yuan
#
#                       born            clean_name
# index
# 0                      NaT           Julie Sweet
# 1      1967-06-14 00:00:00  Kumar Mangalam Birla
# 2      1963-05-27 00:00:00      Shantanu Narayen
# 3      1953-01-31 00:00:00         Garo H. Armen
# 4      1968-02-22 00:00:00       Guillaume Faury
# ...                    ...                   ...
# 171                    nan        Laura J. Alber
# 172    1976-09-24 00:00:00     Stephanie McMahon
# 173                    nan            Greg Creed
# 174                    nan           Rich Barton
# 175    1970-02-20 00:00:00             Eric Yuan
#
# [176 rows x 4 columns]

# %% [markdown]
# ## Joining Data
#
# We start with a simple join between company_ceos_df and exec_df and persist it to the database.  We then check how many companies did not have a match on CEO name.

# %%
exec_df[['clean_name', 'born']]
# Out:
#                clean_name                 born
# 0             Julie Sweet                  NaT
# 1    Kumar Mangalam Birla  1967-06-14 00:00:00
# 2        Shantanu Narayen  1963-05-27 00:00:00
# 3           Garo H. Armen  1953-01-31 00:00:00
# 4         Guillaume Faury  1968-02-22 00:00:00
# ..                    ...                  ...
# 171        Laura J. Alber                  NaN
# 172     Stephanie McMahon  1976-09-24 00:00:00
# 173            Greg Creed                  NaN
# 174           Rich Barton                  NaN
# 175             Eric Yuan  1970-02-20 00:00:00
#
# [176 rows x 2 columns]

# %%
# Remove any duplicate executive entries

exec_df = exec_df.drop_duplicates()

# %%
company_ceos_df[['Executive', 'Company']]
# Out:
#                 Executive                    Company
# 0             Julie Sweet                  Accenture
# 1    Kumar Mangalam Birla         Aditya Birla Group
# 2        Shantanu Narayen              Adobe Systems
# 3           Garo H. Armen                     Agenus
# 4         Guillaume Faury                     Airbus
# ..                    ...                        ...
# 178     Thierry Delaporte                      Wipro
# 179     Stephanie McMahon                        WWE
# 180            Greg Creed                Yum! Brands
# 181           Rich Barton               Zillow Group
# 182             Eric Yuan  Zoom Video Communications
#
# [183 rows x 2 columns]

# %%
company_ceos_df[['Executive', 'Company']].merge(exec_df[['clean_name', 'born']],
                                                left_on=['Executive'],
                                                right_on=['clean_name'])
# Out:
#                 Executive                    Company            clean_name  \
# 0             Julie Sweet                  Accenture           Julie Sweet
# 1    Kumar Mangalam Birla         Aditya Birla Group  Kumar Mangalam Birla
# 2        Shantanu Narayen              Adobe Systems      Shantanu Narayen
# 3           Garo H. Armen                     Agenus         Garo H. Armen
# 4         Guillaume Faury                     Airbus       Guillaume Faury
# ..                    ...                        ...                   ...
# 168        Laura J. Alber            Williams-Sonoma        Laura J. Alber
# 169     Stephanie McMahon                        WWE     Stephanie McMahon
# 170            Greg Creed                Yum! Brands            Greg Creed
# 171           Rich Barton               Zillow Group           Rich Barton
# 172             Eric Yuan  Zoom Video Communications             Eric Yuan
#
#                     born
# 0                    NaT
# 1    1967-06-14 00:00:00
# 2    1963-05-27 00:00:00
# 3    1953-01-31 00:00:00
# 4    1968-02-22 00:00:00
# ..                   ...
# 168                  NaN
# 169  1976-09-24 00:00:00
# 170                  NaN
# 171                  NaN
# 172  1970-02-20 00:00:00
#
# [173 rows x 4 columns]

# %%
temp_df= company_ceos_df.applymap(str)
temp_df.to_sql('company_ceos', conn, if_exists="replace")
temp_df= exec_df.applymap(str)
temp_df.to_sql('executives', conn, if_exists="replace")
company_data_df.to_sql('company_data', conn, if_exists='replace')

pd.read_sql_query('select Executive, Company, born from company_ceos ' +\
                  'join executives on Executive=clean_name ' +\
                  'where born is not null', conn)
# Out:
#                 Executive                    Company                 born
# 0             Julie Sweet                  Accenture                  NaT
# 1    Kumar Mangalam Birla         Aditya Birla Group  1967-06-14 00:00:00
# 2        Shantanu Narayen              Adobe Systems  1963-05-27 00:00:00
# 3           Garo H. Armen                     Agenus  1953-01-31 00:00:00
# 4         Guillaume Faury                     Airbus  1968-02-22 00:00:00
# ..                    ...                        ...                  ...
# 168        Laura J. Alber            Williams-Sonoma                  nan
# 169     Stephanie McMahon                        WWE  1976-09-24 00:00:00
# 170            Greg Creed                Yum! Brands                  nan
# 171           Rich Barton               Zillow Group                  nan
# 172             Eric Yuan  Zoom Video Communications  1970-02-20 00:00:00
#
# [173 rows x 3 columns]

# %% [markdown]
# ###Finding the misses in the join.
#
# Note that the join above resulted in 174 rows.  However, there are more rows in company_ceos_df so we are missing some companies.  We can see which are missed using a left outer join; setting "indicator= True" allows us to see which tuples in company_ceos_df failed to find a match (left_only, e.g. row 24 and 172).

# %%
pd.set_option('display.max_rows', 200)
display(company_ceos_df[['Executive', 'Company']].merge(exec_df[['clean_name', 'born']],
                                                left_on=['Executive'],
                                                right_on=['clean_name'], how="left", indicator=True))
# Out:
#                           Executive                          Company  \
# 0                       Julie Sweet                        Accenture
# 1              Kumar Mangalam Birla               Aditya Birla Group
# 2                  Shantanu Narayen                    Adobe Systems
# 3                     Garo H. Armen                           Agenus
# 4                   Guillaume Faury                           Airbus
# 5                      Daniel Zhang                          Alibaba
# 6                        Andy Jassy                           Amazon
# 7                           Lisa Su           Advanced Micro Devices
# 8                    Stephen Squeri                 American Express
# 9                       Doug Parker          American Airlines Group
# 10                Joseph R. Swedish                           Anthem
# 11                         Tim Cook                            Apple
# 12             Lakshmi Niwas Mittal                   Arcelor Mittal
# 13                     John Stankey                             AT&T
# 14                 Charles Woodburn                      BAE Systems
# 15                    Tapan Singhel  Bajaj Allianz General Insurance
# 16               Carlos Torres Vila  Banco Bilbao Vizcaya Argentaria
# 17                   Brian Moynihan                  Bank of America
# 18                       Jes Staley                         Barclays
# 19                   Warren Buffett               Berkshire Hathaway
# 20                      Hubert Joly                         Best Buy
# 21              Sunil Bharti Mittal               Bharti Enterprises
# 22            Stephen A. Schwarzman                 Blackstone Group
# 23                 Andrew Mackenzie                              BHP
# 24                     Oliver Zipse                              BMW
# 25                     Dave Calhoun                           Boeing
# 26                      Rich Lesser          Boston Consulting Group
# 27                       Bob Dudley                               BP
# 28                  Denise Morrison            Campbell Soup Company
# 29                Mark Shuttleworth                        Canonical
# 30                      Aiman Ezzat                        Capgemini
# 31                 Richard Fairbank            Capital One Financial
# 32                      Jim Umpleby                      Caterpillar
# 33                Evan G. Greenberg                            Chubb
# 34                    Chuck Robbins                    Cisco Systems
# 35                      Jane Fraser                        Citigroup
# 36                    James Quincey                        Coca-Cola
# 37                    Pankaj Mittal                        Codegente
# 38                  Brian Humphries                        Cognizant
# 39                 Brian L. Roberts                          Comcast
# 40                    Tidjane Thiam                    Credit Suisse
# 41                    Ola Källenius                       Daimler AG
# 42                     Michael Dell                             Dell
# 43                       Ed Bastian                  Delta Air Lines
# 44                 Christian Sewing                    Deutsche Bank
# 45                      Frank Appel                    Deutsche Post
# 46                Roland Dickey Jr.            Dickey's Barbecue Pit
# 47                  Edward D. Breen             Dow Chemical Company
# 48                     G. V. Prasad                      Dr. Reddy's
# 49                      Devin Wenig                             eBay
# 50                    Andrew Wilson                  Electronic Arts
# 51                     Börje Ekholm                         Ericsson
# 52                     Darren Woods                       ExxonMobil
# 53                    Lisa S. Jones                     EyeMail Inc.
# 54                 Carmine Di Sibio                    Ernst & Young
# 55                  Mark Zuckerberg                         Facebook
# 56               Frederick W. Smith                            FedEx
# 57                Sergio Marchionne                             Fiat
# 58                  Abigail Johnson             Fidelity Investments
# 59           James Michael Lafferty            Fine Hygienic Holding
# 60                    James Hackett                             Ford
# 61                        Terry Gou                          Foxconn
# 62                  Lachlan Murdoch                  Fox Corporation
# 63                     Daymond John                             FUBU
# 64                  Phebe Novakovic                 General Dynamics
# 65             H. Lawrence Culp Jr.                 General Electric
# 66                    Mary T. Barra                   General Motors
# 67                    Emma Walmsley                  GlaxoSmithKline
# 68                 David M. Solomon                    Goldman Sachs
# 69                    Sundar Pichai                           Google
# 70                     Felipe Gozon                      GMA Network
# 71   Gunupati Venkata Krishna Reddy                   GVK Industries
# 72                    C Vijayakumar                 HCL Technologies
# 73                     Lee Shau Kee       Henderson Land Development
# 74                     Antonio Neri       Hewlett Packard Enterprise
# 75                  Darius Adamczyk                        Honeywell
# 76                    John A. Kaneb                          HP Hood
# 77                       Noel Quinn                             HSBC
# 78                   Arvind Krishna                              IBM
# 79                  Dikesh Malhotra                        IMS Group
# 80                     Salil Parekh                          Infosys
# 81                    Pat Gelsinger                            Intel
# 82                  Millard Drexler                           J.Crew
# 83               Richard B. Handler                  Jefferies Group
# 84                      James Dimon                  JP Morgan Chase
# 85                  Andrew S. Rosen                           Kaplan
# 86                    Pieter Elbers                              KLM
# 87                  Charles G. Koch                  Koch Industries
# 88                      Jeff Clarke                            Kodak
# 89                      Robert Noel                  Land Securities
# 90                 Robert Goldstein                  Las Vegas Sands
# 91                    Andrew Meslow          Bath & Body Works, Inc.
# 92                  Marillyn Hewson                  Lockheed Martin
# 93                       Steve Rowe                  Marks & Spencer
# 94                  Michael Miebach                       Mastercard
# 95                Chris Kempczinski                       McDonald's
# 96                    Kevin Sneader               McKinsey & Company
# 97                Jonathan Ornstein                   Mesa Air Group
# 98              Steven A. Kandarian                          MetLife
# 99                     Isaac Larian                MGA Entertainment
# 100                   Satya Nadella                        Microsoft
# 101               Michael J. Saylor                    MicroStrategy
# 102                 James P. Gorman                   Morgan Stanley
# 103                      Toxey Haas                        Mossy Oak
# 104                     Chris Beard              Mozilla Corporation
# 105                          Vacant              National Amusements
# 106                      Jeff Shell                     NBCUniversal
# 107            Robert James Thomson                        News Corp
# 108                   Mark Thompson           New York Times Company
# 109                   Sapnesh Lalla                             NIIT
# 110                     Mark Parker                             Nike
# 111                  Pekka Lundmark                            Nokia
# 112               Vasant Narasimhan                         Novartis
# 113               Tatsumi Kimishima                         Nintendo
# 114                   Tim Armstrong                             Oath
# 115                      Safra Catz               Oracle Corporation
# 116                       Mark Hurd               Oracle Corporation
# 117                  Ramon Laguarta                          PepsiCo
# 118                   Albert Bourla                           Pfizer
# 119                  Patrice Louvet                Polo Ralph Lauren
# 120                 David S. Taylor                 Procter & Gamble
# 121                 John Strangfeld             Prudential Financial
# 122                      Alan Joyce                           Qantas
# 123                     Anil Ambani                   Reliance Group
# 124                   Mukesh Ambani              Reliance Industries
# 125                     Luca de Meo                          Renault
# 126                  Phiwa Nkambule                           Riovic
# 127                  David I. McKay             Royal Bank of Canada
# 128                     Ross McEwan           Royal Bank of Scotland
# 129                 Ben van Beurden                Royal Dutch Shell
# 130                 Michael O'Leary                          Ryanair
# 131             Douglas L. Peterson                       S&P Global
# 132        Herbert Fisk Johnson III                       SC Johnson
# 133                    Brian Peddle               The Salvation Army
# 134                    Oh-Hyun Kwon                          Samsung
# 135                 Christian Klein                              SAP
# 136                 James Goodnight                    SAS Institute
# 137            Jean-Pascal Tricoire               Schneider Electric
# 138                      Joe Kaeser                          Siemens
# 139                     David Simon             Simon Property Group
# 140                 Chua Sock Koong                          Singtel
# 141                   Masayoshi Son                         SoftBank
# 142                     Tony Aquila                  Solera Holdings
# 143                   Gary C. Kelly               Southwest Airlines
# 144              J. Clifford Hudson                Sonic Corporation
# 145                   Kevin Johnson                        Starbucks
# 146                    Raymond Kwok          Sun Hung Kai Properties
# 147                  Dilip Shanghvi               Sun Pharmaceutical
# 148           William H. Rogers Jr.                   SunTrust Banks
# 149                   Rakesh Khanna                           Syntel
# 150                   Brian Cornell               Target Corporation
# 151               Rajesh Gopinathan        Tata Consultancy Services
# 152                    Li Dongsheng                  TCL Corporation
# 153                       Andy Penn                          Telstra
# 154                        Ho Ching                 Temasek Holdings
# 155                      Dave Lewis                            Tesco
# 156                       Elon Musk                            Tesla
# 157       Umberto Macchi di Cellere                            Tod's
# 158               Alan D. Schnitzer          The Travelers Companies
# 159                     Akio Toyoda                           Toyota
# 160                  Bill Stromberg                     T Rowe Price
# 161                   Parag Agrawal                          Twitter
# 162                     Scott Kirby                  United Airlines
# 163                    Ralph Hamers                              UBS
# 164                  Joseph C. Papa                    Bausch Health
# 165                   Hans Vestberg           Verizon Communications
# 166                   Robert Bakish                        ViacomCBS
# 167                  Vittorio Colao                         Vodafone
# 168                   Herbert Diess                 Volkswagen Group
# 169                       Bill Hilf                           Vulcan
# 170                      Bob Chapek              Walt Disney Company
# 171                 Stefano Pessina         Walgreens Boots Alliance
# 172                   Doug McMillon                          Walmart
# 173                     Ann Sarnoff                  Warner Brothers
# 174                     Jason Kilar                      WarnerMedia
# 175                  Charles Scharf                      Wells Fargo
# 176                     John Mackey               Whole Foods Market
# 177                  Laura J. Alber                  Williams-Sonoma
# 178               Thierry Delaporte                            Wipro
# 179               Stephanie McMahon                              WWE
# 180                      Greg Creed                      Yum! Brands
# 181                     Rich Barton                     Zillow Group
# 182                       Eric Yuan        Zoom Video Communications
#
#                          clean_name                 born     _merge
# 0                       Julie Sweet                  NaT       both
# 1              Kumar Mangalam Birla  1967-06-14 00:00:00       both
# 2                  Shantanu Narayen  1963-05-27 00:00:00       both
# 3                     Garo H. Armen  1953-01-31 00:00:00       both
# 4                   Guillaume Faury  1968-02-22 00:00:00       both
# 5                      Daniel Zhang  1972-01-11 00:00:00       both
# 6                        Andy Jassy  1968-01-13 00:00:00       both
# 7                           Lisa Su  1969-11-07 00:00:00       both
# 8                    Stephen Squeri                  NaT       both
# 9                       Doug Parker  1961-10-31 00:00:00       both
# 10                Joseph R. Swedish  1951-05-17 00:00:00       both
# 11                         Tim Cook  1960-11-01 00:00:00       both
# 12             Lakshmi Niwas Mittal  1950-06-15 00:00:00       both
# 13                     John Stankey                  NaT       both
# 14                 Charles Woodburn                  NaT       both
# 15                    Tapan Singhel  1966-08-12 00:00:00       both
# 16               Carlos Torres Vila                  NaT       both
# 17                   Brian Moynihan  1959-10-09 00:00:00       both
# 18                       Jes Staley  1956-12-27 00:00:00       both
# 19                   Warren Buffett  1930-08-30 00:00:00       both
# 20                      Hubert Joly  1959-08-11 00:00:00       both
# 21              Sunil Bharti Mittal  1957-10-23 00:00:00       both
# 22            Stephen A. Schwarzman  1947-02-14 00:00:00       both
# 23                 Andrew Mackenzie                  NaT       both
# 24                     Oliver Zipse  1964-02-07 00:00:00       both
# 25                     Dave Calhoun  1957-04-18 00:00:00       both
# 26                      Rich Lesser                  NaT       both
# 27                       Bob Dudley  1955-09-14 00:00:00       both
# 28                  Denise Morrison  1954-01-13 00:00:00       both
# 29                Mark Shuttleworth  1973-09-18 00:00:00       both
# 30                              NaN                  NaN  left_only
# 31                 Richard Fairbank  1950-09-18 00:00:00       both
# 32                      Jim Umpleby                  NaT       both
# 33                Evan G. Greenberg                  NaT       both
# 34                    Chuck Robbins                  NaT       both
# 35                      Jane Fraser                  NaT       both
# 36                    James Quincey  1965-01-08 00:00:00       both
# 37                              NaN                  NaN  left_only
# 38                  Brian Humphries                  NaT       both
# 39                 Brian L. Roberts  1959-06-28 00:00:00       both
# 40                    Tidjane Thiam  1962-07-29 00:00:00       both
# 41                              NaN                  NaN  left_only
# 42                     Michael Dell  1965-02-23 00:00:00       both
# 43                       Ed Bastian  1957-06-06 00:00:00       both
# 44                 Christian Sewing  1970-04-24 00:00:00       both
# 45                      Frank Appel                  NaT       both
# 46                Roland Dickey Jr.                  NaT       both
# 47                  Edward D. Breen                  NaT       both
# 48                     G. V. Prasad                  NaT       both
# 49                      Devin Wenig                  NaT       both
# 50                    Andrew Wilson                  NaT       both
# 51                              NaN                  NaN  left_only
# 52                     Darren Woods                  NaT       both
# 53                    Lisa S. Jones  1974-04-01 00:00:00       both
# 54                 Carmine Di Sibio  1963-03-23 00:00:00       both
# 55                  Mark Zuckerberg  1984-05-14 00:00:00       both
# 56               Frederick W. Smith  1944-08-11 00:00:00       both
# 57                Sergio Marchionne                  NaT       both
# 58                  Abigail Johnson  1961-12-19 00:00:00       both
# 59           James Michael Lafferty                  NaT       both
# 60                    James Hackett                  NaT       both
# 61                        Terry Gou  1950-10-18 00:00:00       both
# 62                  Lachlan Murdoch  1971-09-08 00:00:00       both
# 63                     Daymond John  1969-02-23 00:00:00       both
# 64                  Phebe Novakovic                  NaT       both
# 65             H. Lawrence Culp Jr.                  NaT       both
# 66                    Mary T. Barra  1961-12-24 00:00:00       both
# 67                    Emma Walmsley                  NaT       both
# 68                 David M. Solomon                  NaT       both
# 69                    Sundar Pichai  1972-06-10 00:00:00       both
# 70                     Felipe Gozon  1939-12-08 00:00:00       both
# 71   Gunupati Venkata Krishna Reddy  1937-03-22 00:00:00       both
# 72                    C Vijayakumar                  NaT       both
# 73                     Lee Shau Kee  1928-03-07 00:00:00       both
# 74                     Antonio Neri  1576-02-29 00:00:00       both
# 75                  Darius Adamczyk  1966-02-08 00:00:00       both
# 76                    John A. Kaneb  1934-12-14 00:00:00       both
# 77                       Noel Quinn                  NaN       both
# 78                   Arvind Krishna                  NaN       both
# 79                  Dikesh Malhotra                  NaN       both
# 80                     Salil Parekh  1964-06-05 00:00:00       both
# 81                    Pat Gelsinger  1961-03-05 00:00:00       both
# 82                  Millard Drexler  1944-08-17 00:00:00       both
# 83               Richard B. Handler  1961-05-23 00:00:00       both
# 84                      James Dimon  1956-03-13 00:00:00       both
# 85                  Andrew S. Rosen                  NaN       both
# 86                    Pieter Elbers  1970-05-11 00:00:00       both
# 87                  Charles G. Koch  1935-11-01 00:00:00       both
# 88                      Jeff Clarke                  NaN       both
# 89                      Robert Noel                  NaN       both
# 90                 Robert Goldstein                  NaN       both
# 91                              NaN                  NaN  left_only
# 92                  Marillyn Hewson  1953-12-27 00:00:00       both
# 93                       Steve Rowe  1965-01-19 00:00:00       both
# 94                              NaN                  NaN  left_only
# 95                Chris Kempczinski                  NaN       both
# 96                    Kevin Sneader                  NaN       both
# 97                Jonathan Ornstein                  NaN       both
# 98              Steven A. Kandarian                  NaN       both
# 99                     Isaac Larian  1954-03-28 00:00:00       both
# 100                   Satya Nadella  1967-08-19 00:00:00       both
# 101               Michael J. Saylor  1965-02-04 00:00:00       both
# 102                 James P. Gorman  1958-07-14 00:00:00       both
# 103                      Toxey Haas  1960-01-21 00:00:00       both
# 104                     Chris Beard  1973-02-18 00:00:00       both
# 105                          Vacant                  NaN       both
# 106                      Jeff Shell                  NaN       both
# 107            Robert James Thomson  1961-03-11 00:00:00       both
# 108                   Mark Thompson                  NaN       both
# 109                             NaN                  NaN  left_only
# 110                     Mark Parker  1955-10-21 00:00:00       both
# 111                  Pekka Lundmark  1963-12-09 00:00:00       both
# 112               Vasant Narasimhan                  NaN       both
# 113               Tatsumi Kimishima  1950-04-21 00:00:00       both
# 114                   Tim Armstrong  1965-11-25 00:00:00       both
# 115                      Safra Catz  1961-12-01 00:00:00       both
# 116                       Mark Hurd  1957-01-01 00:00:00       both
# 117                  Ramon Laguarta                  NaN       both
# 118                   Albert Bourla  1961-10-21 00:00:00       both
# 119                  Patrice Louvet                  NaN       both
# 120                 David S. Taylor  1958-04-20 00:00:00       both
# 121                 John Strangfeld                  NaN       both
# 122                      Alan Joyce  1942-10-21 00:00:00       both
# 123                     Anil Ambani  1959-06-04 00:00:00       both
# 124                   Mukesh Ambani  1957-04-19 00:00:00       both
# 125                     Luca de Meo  1967-06-13 00:00:00       both
# 126                  Phiwa Nkambule  1992-01-24 00:00:00       both
# 127                  David I. McKay                  NaN       both
# 128                     Ross McEwan  1957-07-16 00:00:00       both
# 129                 Ben van Beurden  1958-04-23 00:00:00       both
# 130                             NaN                  NaN  left_only
# 131             Douglas L. Peterson                  NaN       both
# 132        Herbert Fisk Johnson III  1958-05-19 00:00:00       both
# 133                    Brian Peddle  1957-08-08 00:00:00       both
# 134                    Oh-Hyun Kwon  1952-10-15 00:00:00       both
# 135                 Christian Klein  1980-05-04 00:00:00       both
# 136                 James Goodnight                  NaN       both
# 137            Jean-Pascal Tricoire  1963-05-11 00:00:00       both
# 138                      Joe Kaeser  1957-06-23 00:00:00       both
# 139                     David Simon  1960-02-09 00:00:00       both
# 140                 Chua Sock Koong                  NaN       both
# 141                   Masayoshi Son  1957-08-11 00:00:00       both
# 142                     Tony Aquila                  NaN       both
# 143                   Gary C. Kelly  1955-03-12 00:00:00       both
# 144              J. Clifford Hudson                  NaN       both
# 145                   Kevin Johnson                  NaN       both
# 146                    Raymond Kwok                  NaN       both
# 147                  Dilip Shanghvi  1955-10-01 00:00:00       both
# 148           William H. Rogers Jr.                  NaN       both
# 149                   Rakesh Khanna                  NaN       both
# 150                   Brian Cornell                  NaN       both
# 151               Rajesh Gopinathan                  NaN       both
# 152                    Li Dongsheng                  NaN       both
# 153                       Andy Penn                  NaN       both
# 154                        Ho Ching  1953-03-27 00:00:00       both
# 155                      Dave Lewis                  NaN       both
# 156                       Elon Musk  1971-06-28 00:00:00       both
# 157                             NaN                  NaN  left_only
# 158               Alan D. Schnitzer                  NaN       both
# 159                     Akio Toyoda  1956-05-03 00:00:00       both
# 160                  Bill Stromberg                  NaN       both
# 161                   Parag Agrawal  1984-05-21 00:00:00       both
# 162                     Scott Kirby  1967-08-13 00:00:00       both
# 163                    Ralph Hamers  1966-05-25 00:00:00       both
# 164                  Joseph C. Papa  1955-10-01 00:00:00       both
# 165                   Hans Vestberg  1965-06-23 00:00:00       both
# 166                   Robert Bakish  1963-12-14 00:00:00       both
# 167                  Vittorio Colao  1961-10-03 00:00:00       both
# 168                   Herbert Diess  1958-10-24 00:00:00       both
# 169                       Bill Hilf                  NaN       both
# 170                      Bob Chapek                  NaN       both
# 171                 Stefano Pessina  1941-06-04 00:00:00       both
# 172                   Doug McMillon  1966-10-17 00:00:00       both
# 173                     Ann Sarnoff                  NaN       both
# 174                     Jason Kilar  1971-04-26 00:00:00       both
# 175                  Charles Scharf  1965-04-24 00:00:00       both
# 176                     John Mackey                  NaN       both
# 177                  Laura J. Alber                  NaN       both
# 178                             NaN                  NaN  left_only
# 179               Stephanie McMahon  1976-09-24 00:00:00       both
# 180                      Greg Creed                  NaN       both
# 181                     Rich Barton                  NaN       both
# 182                       Eric Yuan  1970-02-20 00:00:00       both

# %%
pd.set_option('display.max_rows', 50)
result_df = company_ceos_df[['Executive', 'Company']].merge(exec_df[['clean_name', 'born']],
                                                left_on=['Executive'],
                                                right_on=['clean_name'], how="outer", indicator=True)

result_df[result_df['_merge'] != 'both']
# Out:
#                      Executive                  Company          clean_name  \
# 30                 Aiman Ezzat                Capgemini                 NaN
# 37               Pankaj Mittal                Codegente                 NaN
# 41               Ola Källenius               Daimler AG                 NaN
# 51                Börje Ekholm                 Ericsson                 NaN
# 91               Andrew Meslow  Bath & Body Works, Inc.                 NaN
# 94             Michael Miebach               Mastercard                 NaN
# 109              Sapnesh Lalla                     NIIT                 NaN
# 130            Michael O'Leary                  Ryanair                 NaN
# 157  Umberto Macchi di Cellere                    Tod's                 NaN
# 178          Thierry Delaporte                    Wipro                 NaN
# 183                        NaN                      NaN  Ola K%C3%A4llenius
# 184                        NaN                      NaN   B%C3%B6rje Ekholm
# 185                        NaN                      NaN   Michael O%27Leary
#
#                     born      _merge
# 30                   NaN   left_only
# 37                   NaN   left_only
# 41                   NaN   left_only
# 51                   NaN   left_only
# 91                   NaN   left_only
# 94                   NaN   left_only
# 109                  NaN   left_only
# 130                  NaN   left_only
# 157                  NaN   left_only
# 178                  NaN   left_only
# 183  1969-06-11 00:00:00  right_only
# 184                  NaT  right_only
# 185                  NaN  right_only

# %% [markdown]
# ## Composing Joins

# %%
pd.read_sql_query('select Executive, Company, born  from company_ceos ' +\
                  'join executives on Executive=clean_name join company_data cd on Company=cd.name ' +\
                  'where born is not null', conn)
# Out:
#                Executive                 Company                 born
# 0          Garo H. Armen                  Agenus  1953-01-31 00:00:00
# 1           Daniel Zhang                 Alibaba  1972-01-11 00:00:00
# 2             Andy Jassy                  Amazon  1968-01-13 00:00:00
# 3       Charles Woodburn             BAE Systems                  NaT
# 4      Mark Shuttleworth               Canonical  1973-09-18 00:00:00
# 5       Brian L. Roberts                 Comcast  1959-06-28 00:00:00
# 6            Devin Wenig                    eBay                  NaT
# 7        Mark Zuckerberg                Facebook  1984-05-14 00:00:00
# 8        Phebe Novakovic        General Dynamics                  NaT
# 9   H. Lawrence Culp Jr.        General Electric                  NaT
# 10         Sundar Pichai                  Google  1972-06-10 00:00:00
# 11       Darius Adamczyk               Honeywell  1966-02-08 00:00:00
# 12       Marillyn Hewson         Lockheed Martin  1953-12-27 00:00:00
# 13     Jonathan Ornstein          Mesa Air Group                  nan
# 14  Robert James Thomson               News Corp  1961-03-11 00:00:00
# 15            Joe Kaeser                 Siemens  1957-06-23 00:00:00
# 16         Kevin Johnson               Starbucks                  nan
# 17            Dave Lewis                   Tesco                  nan
# 18         Parag Agrawal                 Twitter  1984-05-21 00:00:00
# 19         Hans Vestberg  Verizon Communications  1965-06-23 00:00:00

# %%
pd.read_sql_query('select * from company_ceos ' +\
                  'join executives on Executive=clean_name join company_data cd on Company=cd.name ' +\
                  'where born is not null', conn)
# Out:
#     index                 Company             Executive  \
# 0       3                  Agenus         Garo H. Armen
# 1       5                 Alibaba          Daniel Zhang
# 2       6                  Amazon            Andy Jassy
# 3      14             BAE Systems      Charles Woodburn
# 4      29               Canonical     Mark Shuttleworth
# 5      39                 Comcast      Brian L. Roberts
# 6      49                    eBay           Devin Wenig
# 7      55                Facebook       Mark Zuckerberg
# 8      64        General Dynamics       Phebe Novakovic
# 9      65        General Electric  H. Lawrence Culp Jr.
# 10     69                  Google         Sundar Pichai
# 11     75               Honeywell       Darius Adamczyk
# 12     92         Lockheed Martin       Marillyn Hewson
# 13     97          Mesa Air Group     Jonathan Ornstein
# 14    107               News Corp  Robert James Thomson
# 15    138                 Siemens            Joe Kaeser
# 16    145               Starbucks         Kevin Johnson
# 17    155                   Tesco            Dave Lewis
# 18    161                 Twitter         Parag Agrawal
# 19    165  Verizon Communications         Hans Vestberg
#
#                                Title Since  \
# 0          Founder, chairman, CEO[4]  1994
# 1                             CEO[6]  2015
# 2               CEO and president[7]  2021
# 3        Chief Executive Officer[15]  2008
# 4                Founder and CEO[29]  2017
# 5               Chairman and CEO[39]  2002
# 6              President and CEO[47]  2015
# 7                   Chairman and CEO  2004
# 8               Chairman and CEO[57]  2014
# 9                   Chairman and CEO  2018
# 10                           CEO[61]  2015
# 11  Chairman, President, and CEO[67]  2017
# 12   Chairman, president and CEO[81]  2013
# 13              Chairman and CEO[85]  1998
# 14                           CEO[93]  2013
# 15            President and CEO[121]  2013
# 16            President and CEO[128]  2017
# 17                    Group CEO[138]  2014
# 18                          CEO[144]  2021
# 19             Chairman and CEO[148]  2018
#
#                                                                                      Notes  \
# 0                                           Founder of the Children of Armenia Fund (COAF)
# 1                                                                   Previously with Taobao
# 2                                                                                      nan
# 3                                                                       Succeeded Ian King
# 4                                          Stepped down as CEO in 2009 and resumed in 2017
# 5                                          Son of Ralph J. Roberts, the founder of Comcast
# 6                             Third CEO of the company, after Meg Whitman and John Donahoe
# 7                                                              Co-founded Facebook in 2004
# 8   Worked for the Central Intelligence Agency and the United States Department of Defense
# 9              Prior to joining GE, Culp worked at Danaher Corporation in Washington, D.C.
# 10                                      Former director of Jive Software from 2011 to 2013
# 11                                    Succeeded David M. Cote (now the executive chairman)
# 12                     Also serves on the board of Sandia National Laboratories and DuPont
# 13                                     Formerly led Virgin Express and Continental Express
# 14                                   Previously managing editor of The Wall Street Journal
# 15                                                                  Succeeds Peter Löscher
# 16                            Previously CEO for Juniper Networks; succeeds Howard Schultz
# 17                                                                Previously with Unilever
# 18                                                                   Succeeded Jack Dorsey
# 19                                                                  Replaced Lowell McAdam
#
#        Updated  index                  name  \
# 0   2018-10-01      3         Garo_H._Armen
# 1   2018-10-01      5          Daniel_Zhang
# 2          nan      6            Andy_Jassy
# 3   2018-10-01     14      Charles_Woodburn
# 4   2017-11-14     29     Mark_Shuttleworth
# 5   2017-11-14     37      Brian_L._Roberts
# 6   2017-11-14     47           Devin_Wenig
# 7   2017-11-14     53       Mark_Zuckerberg
# 8   2017-11-14     62       Phebe_Novakovic
# 9   2018-10-01     63  H._Lawrence_Culp_Jr.
# 10  2017-11-13     67         Sundar_Pichai
# 11  2017-11-13     73       Darius_Adamczyk
# 12  2017-11-13     89       Marillyn_Hewson
# 13  2017-11-13     93     Jonathan_Ornstein
# 14  2017-11-12    103  Robert_James_Thomson
# 15  2017-11-12    133            Joe_Kaeser
# 16  2017-11-11    140         Kevin_Johnson
# 17  2017-11-11    150            Dave_Lewis
# 18  2021-11-30    155         Parag_Agrawal
# 19  2019-03-31    159         Hans_Vestberg
#
#                                                   page  ... state_code  \
# 0          https://en.wikipedia.org/wiki/Garo_H._Armen  ...         MA
# 1           https://en.wikipedia.org/wiki/Daniel_Zhang  ...       None
# 2             https://en.wikipedia.org/wiki/Andy_Jassy  ...         WA
# 3       https://en.wikipedia.org/wiki/Charles_Woodburn  ...         MD
# 4      https://en.wikipedia.org/wiki/Mark_Shuttleworth  ...       None
# 5       https://en.wikipedia.org/wiki/Brian_L._Roberts  ...         PA
# 6            https://en.wikipedia.org/wiki/Devin_Wenig  ...         CA
# 7        https://en.wikipedia.org/wiki/Mark_Zuckerberg  ...         CA
# 8        https://en.wikipedia.org/wiki/Phebe_Novakovic  ...         VA
# 9   https://en.wikipedia.org/wiki/H._Lawrence_Culp_Jr.  ...         CT
# 10         https://en.wikipedia.org/wiki/Sundar_Pichai  ...         CA
# 11       https://en.wikipedia.org/wiki/Darius_Adamczyk  ...         NJ
# 12       https://en.wikipedia.org/wiki/Marillyn_Hewson  ...         MD
# 13     https://en.wikipedia.org/wiki/Jonathan_Ornstein  ...         AZ
# 14  https://en.wikipedia.org/wiki/Robert_James_Thomson  ...         NY
# 15            https://en.wikipedia.org/wiki/Joe_Kaeser  ...       None
# 16         https://en.wikipedia.org/wiki/Kevin_Johnson  ...         WA
# 17            https://en.wikipedia.org/wiki/Dave_Lewis  ...       None
# 18         https://en.wikipedia.org/wiki/Parag_Agrawal  ...         CA
# 19         https://en.wikipedia.org/wiki/Hans_Vestberg  ...         NY
#
#               region           city funding_rounds  founded_at founded_month  \
# 0             Boston      Lexington              2  01/01/1994       1994-01
# 1           Hangzhou       Hangzhou              4  01/06/1999       1999-06
# 2            Seattle        Seattle              1  01/01/1994       1994-01
# 3   Washington, D.C.      Rockville              2  01/11/1999       1999-11
# 4             London         London              1  01/01/2004       2004-01
# 5       Philadelphia   Philadelphia              1  01/01/1963       1963-01
# 6        SF Bay Area       San Jose              1  01/09/1995       1995-09
# 7        SF Bay Area     Menlo Park             11  04/02/2004       2004-02
# 8   Washington, D.C.   Falls Church              3  01/01/1952       1952-01
# 9           Hartford      Fairfield              1  1890-01-01          None
# 10       SF Bay Area  Mountain View              2  07/09/1998       1998-09
# 11            Newark     Morristown              1  23/04/1985       1985-04
# 12  Washington, D.C.       Bethesda              2  01/03/1995       1995-03
# 13           Phoenix        Phoenix              1  01/01/1982       1982-01
# 14     New York City       New York              1  01/01/1980       1980-01
# 15            Munich         Munich              1  1847-01-01          None
# 16           Seattle        Seattle              1  30/03/1971       1971-03
# 17       GBR - Other       Cheshunt              2  01/01/1919       1919-01
# 18       SF Bay Area  San Francisco              8  21/03/2006       2006-03
# 19     New York City       New York              5  07/10/1983       1983-10
#
#    founded_quarter founded_year first_funding_at last_funding_at
# 0          1994-Q1       1994.0       04/08/2009      25/04/2013
# 1          1999-Q2       1999.0       01/10/1999      11/08/2005
# 2          1994-Q1       1994.0       01/07/1995      01/07/1995
# 3          1999-Q4       1999.0       30/11/2009      10/09/2010
# 4          2004-Q1       2004.0       16/08/2013      16/08/2013
# 5          1963-Q1       1963.0       08/05/2013      08/05/2013
# 6          1995-Q3       1995.0       01/06/1997      01/06/1997
# 7          2004-Q1       2004.0       01/09/2004      21/01/2011
# 8          1952-Q1       1952.0       05/08/2009      10/09/2010
# 9             None          NaN       19/11/2009      19/11/2009
# 10         1998-Q3       1998.0       01/08/1998      07/06/1999
# 11         1985-Q2       1985.0       27/10/2009      27/10/2009
# 12         1995-Q1       1995.0       06/07/2009      22/11/2010
# 13         1982-Q1       1982.0       13/08/2014      13/08/2014
# 14         1980-Q1       1980.0       08/01/2010      08/01/2010
# 15            None          NaN       19/07/2010      19/07/2010
# 16         1971-Q1       1971.0       01/02/1991      01/02/1991
# 17         1919-Q1       1919.0       30/07/2009      15/07/2010
# 18         2006-Q1       2006.0       01/07/2007      08/09/2011
# 19         1983-Q4       1983.0       26/01/2010      28/02/2014
#
# [20 rows x 31 columns]

# %%
company_ceos_df.merge(exec_df,
                      left_on=['Executive'],
                      right_on=['clean_name']).\
                      merge(company_data_df,
                            left_on='Company',
                            right_on='name')
# Out:
#                    Company             Executive  \
# 0                   Agenus         Garo H. Armen
# 1                  Alibaba          Daniel Zhang
# 2                   Amazon            Andy Jassy
# 3              BAE Systems      Charles Woodburn
# 4                Canonical     Mark Shuttleworth
# 5                  Comcast      Brian L. Roberts
# 6                     eBay           Devin Wenig
# 7                 Facebook       Mark Zuckerberg
# 8         General Dynamics       Phebe Novakovic
# 9         General Electric  H. Lawrence Culp Jr.
# 10                  Google         Sundar Pichai
# 11               Honeywell       Darius Adamczyk
# 12         Lockheed Martin       Marillyn Hewson
# 13          Mesa Air Group     Jonathan Ornstein
# 14               News Corp  Robert James Thomson
# 15                 Siemens            Joe Kaeser
# 16               Starbucks         Kevin Johnson
# 17                   Tesco            Dave Lewis
# 18                 Twitter         Parag Agrawal
# 19  Verizon Communications         Hans Vestberg
#
#                                Title Since  \
# 0          Founder, chairman, CEO[4]  1994
# 1                             CEO[6]  2015
# 2               CEO and president[7]  2021
# 3        Chief Executive Officer[15]  2008
# 4                Founder and CEO[29]  2017
# 5               Chairman and CEO[39]  2002
# 6              President and CEO[47]  2015
# 7                   Chairman and CEO  2004
# 8               Chairman and CEO[57]  2014
# 9                   Chairman and CEO  2018
# 10                           CEO[61]  2015
# 11  Chairman, President, and CEO[67]  2017
# 12   Chairman, president and CEO[81]  2013
# 13              Chairman and CEO[85]  1998
# 14                           CEO[93]  2013
# 15            President and CEO[121]  2013
# 16            President and CEO[128]  2017
# 17                    Group CEO[138]  2014
# 18                          CEO[144]  2021
# 19             Chairman and CEO[148]  2018
#
#                                                                                      Notes  \
# 0                                           Founder of the Children of Armenia Fund (COAF)
# 1                                                                   Previously with Taobao
# 2                                                                                      NaN
# 3                                                                       Succeeded Ian King
# 4                                          Stepped down as CEO in 2009 and resumed in 2017
# 5                                          Son of Ralph J. Roberts, the founder of Comcast
# 6                             Third CEO of the company, after Meg Whitman and John Donahoe
# 7                                                              Co-founded Facebook in 2004
# 8   Worked for the Central Intelligence Agency and the United States Department of Defense
# 9              Prior to joining GE, Culp worked at Danaher Corporation in Washington, D.C.
# 10                                      Former director of Jive Software from 2011 to 2013
# 11                                    Succeeded David M. Cote (now the executive chairman)
# 12                     Also serves on the board of Sandia National Laboratories and DuPont
# 13                                     Formerly led Virgin Express and Continental Express
# 14                                   Previously managing editor of The Wall Street Journal
# 15                                                                  Succeeds Peter Löscher
# 16                            Previously CEO for Juniper Networks; succeeds Howard Schultz
# 17                                                                Previously with Unilever
# 18                                                                   Succeeded Jack Dorsey
# 19                                                                  Replaced Lowell McAdam
#
#        Updated                name_x  \
# 0   2018-10-01         Garo_H._Armen
# 1   2018-10-01          Daniel_Zhang
# 2          NaN            Andy_Jassy
# 3   2018-10-01      Charles_Woodburn
# 4   2017-11-14     Mark_Shuttleworth
# 5   2017-11-14      Brian_L._Roberts
# 6   2017-11-14           Devin_Wenig
# 7   2017-11-14       Mark_Zuckerberg
# 8   2017-11-14       Phebe_Novakovic
# 9   2018-10-01  H._Lawrence_Culp_Jr.
# 10  2017-11-13         Sundar_Pichai
# 11  2017-11-13       Darius_Adamczyk
# 12  2017-11-13       Marillyn_Hewson
# 13  2017-11-13     Jonathan_Ornstein
# 14  2017-11-12  Robert_James_Thomson
# 15  2017-11-12            Joe_Kaeser
# 16  2017-11-11         Kevin_Johnson
# 17  2017-11-11            Dave_Lewis
# 18  2021-11-30         Parag_Agrawal
# 19  2019-03-31         Hans_Vestberg
#
#                                                   page                 born  \
# 0          https://en.wikipedia.org/wiki/Garo_H._Armen  1953-01-31 00:00:00
# 1           https://en.wikipedia.org/wiki/Daniel_Zhang  1972-01-11 00:00:00
# 2             https://en.wikipedia.org/wiki/Andy_Jassy  1968-01-13 00:00:00
# 3       https://en.wikipedia.org/wiki/Charles_Woodburn                  NaT
# 4      https://en.wikipedia.org/wiki/Mark_Shuttleworth  1973-09-18 00:00:00
# 5       https://en.wikipedia.org/wiki/Brian_L._Roberts  1959-06-28 00:00:00
# 6            https://en.wikipedia.org/wiki/Devin_Wenig                  NaT
# 7        https://en.wikipedia.org/wiki/Mark_Zuckerberg  1984-05-14 00:00:00
# 8        https://en.wikipedia.org/wiki/Phebe_Novakovic                  NaT
# 9   https://en.wikipedia.org/wiki/H._Lawrence_Culp_Jr.                  NaT
# 10         https://en.wikipedia.org/wiki/Sundar_Pichai  1972-06-10 00:00:00
# 11       https://en.wikipedia.org/wiki/Darius_Adamczyk  1966-02-08 00:00:00
# 12       https://en.wikipedia.org/wiki/Marillyn_Hewson  1953-12-27 00:00:00
# 13     https://en.wikipedia.org/wiki/Jonathan_Ornstein                  NaN
# 14  https://en.wikipedia.org/wiki/Robert_James_Thomson  1961-03-11 00:00:00
# 15            https://en.wikipedia.org/wiki/Joe_Kaeser  1957-06-23 00:00:00
# 16         https://en.wikipedia.org/wiki/Kevin_Johnson                  NaN
# 17            https://en.wikipedia.org/wiki/Dave_Lewis                  NaN
# 18         https://en.wikipedia.org/wiki/Parag_Agrawal  1984-05-21 00:00:00
# 19         https://en.wikipedia.org/wiki/Hans_Vestberg  1965-06-23 00:00:00
#
#               clean_name  ... state_code            region           city  \
# 0          Garo H. Armen  ...         MA            Boston      Lexington
# 1           Daniel Zhang  ...        NaN          Hangzhou       Hangzhou
# 2             Andy Jassy  ...         WA           Seattle        Seattle
# 3       Charles Woodburn  ...         MD  Washington, D.C.      Rockville
# 4      Mark Shuttleworth  ...        NaN            London         London
# 5       Brian L. Roberts  ...         PA      Philadelphia   Philadelphia
# 6            Devin Wenig  ...         CA       SF Bay Area       San Jose
# 7        Mark Zuckerberg  ...         CA       SF Bay Area     Menlo Park
# 8        Phebe Novakovic  ...         VA  Washington, D.C.   Falls Church
# 9   H. Lawrence Culp Jr.  ...         CT          Hartford      Fairfield
# 10         Sundar Pichai  ...         CA       SF Bay Area  Mountain View
# 11       Darius Adamczyk  ...         NJ            Newark     Morristown
# 12       Marillyn Hewson  ...         MD  Washington, D.C.       Bethesda
# 13     Jonathan Ornstein  ...         AZ           Phoenix        Phoenix
# 14  Robert James Thomson  ...         NY     New York City       New York
# 15            Joe Kaeser  ...        NaN            Munich         Munich
# 16         Kevin Johnson  ...         WA           Seattle        Seattle
# 17            Dave Lewis  ...        NaN       GBR - Other       Cheshunt
# 18         Parag Agrawal  ...         CA       SF Bay Area  San Francisco
# 19         Hans Vestberg  ...         NY     New York City       New York
#
#    funding_rounds  founded_at founded_month founded_quarter founded_year  \
# 0               2  01/01/1994       1994-01         1994-Q1       1994.0
# 1               4  01/06/1999       1999-06         1999-Q2       1999.0
# 2               1  01/01/1994       1994-01         1994-Q1       1994.0
# 3               2  01/11/1999       1999-11         1999-Q4       1999.0
# 4               1  01/01/2004       2004-01         2004-Q1       2004.0
# 5               1  01/01/1963       1963-01         1963-Q1       1963.0
# 6               1  01/09/1995       1995-09         1995-Q3       1995.0
# 7              11  04/02/2004       2004-02         2004-Q1       2004.0
# 8               3  01/01/1952       1952-01         1952-Q1       1952.0
# 9               1  1890-01-01           NaN             NaN          NaN
# 10              2  07/09/1998       1998-09         1998-Q3       1998.0
# 11              1  23/04/1985       1985-04         1985-Q2       1985.0
# 12              2  01/03/1995       1995-03         1995-Q1       1995.0
# 13              1  01/01/1982       1982-01         1982-Q1       1982.0
# 14              1  01/01/1980       1980-01         1980-Q1       1980.0
# 15              1  1847-01-01           NaN             NaN          NaN
# 16              1  30/03/1971       1971-03         1971-Q1       1971.0
# 17              2  01/01/1919       1919-01         1919-Q1       1919.0
# 18              8  21/03/2006       2006-03         2006-Q1       2006.0
# 19              5  07/10/1983       1983-10         1983-Q4       1983.0
#
#    first_funding_at last_funding_at
# 0        04/08/2009      25/04/2013
# 1        01/10/1999      11/08/2005
# 2        01/07/1995      01/07/1995
# 3        30/11/2009      10/09/2010
# 4        16/08/2013      16/08/2013
# 5        08/05/2013      08/05/2013
# 6        01/06/1997      01/06/1997
# 7        01/09/2004      21/01/2011
# 8        05/08/2009      10/09/2010
# 9        19/11/2009      19/11/2009
# 10       01/08/1998      07/06/1999
# 11       27/10/2009      27/10/2009
# 12       06/07/2009      22/11/2010
# 13       13/08/2014      13/08/2014
# 14       08/01/2010      08/01/2010
# 15       19/07/2010      19/07/2010
# 16       01/02/1991      01/02/1991
# 17       30/07/2009      15/07/2010
# 18       01/07/2007      08/09/2011
# 19       26/01/2010      28/02/2014
#
# [20 rows x 28 columns]

# %% [markdown]
# # Lecture Module 3: Validating and Cleaning Data
#
# How do we know our data is good?  We can create rules that trigger when the data fails some particular set of **constraints**.

# %%
# Test with validation rules

replace_item = ''

failed = False
for name in exec_df['clean_name']:
  if not name.replace(' ', replace_item).\
          replace('.', replace_item).\
          replace('\'',replace_item).\
          replace('-',replace_item).isalpha():
    print ("Illegal name %s"%name)
    failed = True

if failed:
  print('Found illegal names!')
# Out:
# Illegal name Ola K%C3%A4llenius
# Illegal name B%C3%B6rje Ekholm
# Illegal name Michael O%27Leary
# Found illegal names!

# %% [markdown]
# ## Data Cleaning: Fixing the Errors
#
# One approach we could take is to realize that these are all strings in which accented characters are specially coded for use in (Wikipedia) URLs.  For instance, %C3 is a hex character code for an accented "u".  We can use a function called `unqote` to fix this...

# %%
from urllib.parse import unquote

exec_df['clean_name'].apply(unquote)
# Out:
# 0               Julie Sweet
# 1      Kumar Mangalam Birla
# 2          Shantanu Narayen
# 3             Garo H. Armen
# 4           Guillaume Faury
#                ...
# 171          Laura J. Alber
# 172       Stephanie McMahon
# 173              Greg Creed
# 174             Rich Barton
# 175               Eric Yuan
# Name: clean_name, Length: 176, dtype: object

# %% [markdown]
# ## More Generally: Data Validation Tools
#
# Are there tools to help us validate data?  Of course!  We see an [example](https://validators.readthedocs.io/en/latest/) of one such tool, simply called `validators`, below.  There are many others in the data cleaning literature.

# %%
# !pip install validators
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: validators in /usr/local/lib/python3.7/dist-packages (0.20.0)
# Requirement already satisfied: decorator>=3.4.0 in /usr/local/lib/python3.7/dist-packages (from validators) (4.4.2)

# %%
import validators.url

# Are all of the URLs valid?
exec_df['page'].apply(validators.url)
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 171    True
# 172    True
# 173    True
# 174    True
# 175    True
# Name: page, Length: 176, dtype: bool

# %% [markdown]
# ## Validation against a master list
#
# We can also compare against "master" lists (in tables).  For example, company info about stock ticker symbols can be compared against the full list of symbols; states and countries can be compared against definitive lists.
#
# Suppose we want to confirm that `company_data_df` has valid country codes.

# %%
company_data_df[['name','country_code']]
# Out:
#                                 name country_code
# 0                           #waywire          USA
# 1                 &TV Communications          USA
# 2                  'Rock' Your Paper          EST
# 3                  (In)Touch Network          GBR
# 4                         +n (PlusN)          USA
# ...                              ...          ...
# 47753                          Zzish          GBR
# 47754  ZZNode Science and Technology          CHN
# 47755          Zzzzapp Wireless ltd.          HRV
# 47756                  [a]list games          NaN
# 47757                          [x+1]          USA
#
# [47758 rows x 2 columns]

# %% [markdown]
# TSome of these are NaNs -- let's drop them...

# %% [markdown]
# From someone's Github content, here's a nice list of all countries and region codes.

# %%
countries_df = pd.read_csv("https://raw.githubusercontent.com/lukes/ISO-3166-Countries-with-Regional-Codes/master/all/all.csv")

display(countries_df)
# Out:
#                   name alpha-2 alpha-3  country-code     iso_3166-2   region  \
# 0          Afghanistan      AF     AFG             4  ISO 3166-2:AF     Asia
# 1        Åland Islands      AX     ALA           248  ISO 3166-2:AX   Europe
# 2              Albania      AL     ALB             8  ISO 3166-2:AL   Europe
# 3              Algeria      DZ     DZA            12  ISO 3166-2:DZ   Africa
# 4       American Samoa      AS     ASM            16  ISO 3166-2:AS  Oceania
# ..                 ...     ...     ...           ...            ...      ...
# 244  Wallis and Futuna      WF     WLF           876  ISO 3166-2:WF  Oceania
# 245     Western Sahara      EH     ESH           732  ISO 3166-2:EH   Africa
# 246              Yemen      YE     YEM           887  ISO 3166-2:YE     Asia
# 247             Zambia      ZM     ZMB           894  ISO 3166-2:ZM   Africa
# 248           Zimbabwe      ZW     ZWE           716  ISO 3166-2:ZW   Africa
#
#              sub-region intermediate-region  region-code  sub-region-code  \
# 0         Southern Asia                 NaN        142.0             34.0
# 1       Northern Europe                 NaN        150.0            154.0
# 2       Southern Europe                 NaN        150.0             39.0
# 3       Northern Africa                 NaN          2.0             15.0
# 4             Polynesia                 NaN          9.0             61.0
# ..                  ...                 ...          ...              ...
# 244           Polynesia                 NaN          9.0             61.0
# 245     Northern Africa                 NaN          2.0             15.0
# 246        Western Asia                 NaN        142.0            145.0
# 247  Sub-Saharan Africa      Eastern Africa          2.0            202.0
# 248  Sub-Saharan Africa      Eastern Africa          2.0            202.0
#
#      intermediate-region-code
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ..                        ...
# 244                       NaN
# 245                       NaN
# 246                       NaN
# 247                      14.0
# 248                      14.0
#
# [249 rows x 11 columns]

# %%
validated = company_data_df.merge(countries_df, left_on=['country_code'], right_on=['alpha-3'],
                      how='left', indicator=True)

validated[validated['_merge'] != 'both']
# Out:
#                              permalink             name_x  \
# 8                /organization/0-6-com            0-6.com
# 19          /organization/1000-markets       1000 Markets
# 25              /organization/100du-tv           100du.tv
# 30                 /organization/10sec              10sec
# 35     /organization/115-network-disks  115 network disks
# ...                                ...                ...
# 47707               /organization/zura              Zura!
# 47712            /organization/zursh-2              Zursh
# 47729          /organization/zwoor-com          zwoor.com
# 47743              /organization/zympi              Zympi
# 47756       /organization/a-list-games      [a]list games
#
#                      homepage_url  \
# 8              http://www.0-6.com
# 19     http://www.1000markets.com
# 25           http://www.100du.com
# 30                 http://10s.ec/
# 35            http://www.115.com/
# ...                           ...
# 47707      http://www.zura.com.br
# 47712       http://www.zursh.com/
# 47729        http://www.zwoor.com
# 47743        http://www.zympi.com
# 47756   http://www.alistgames.com
#
#                                                               category_list  \
# 8                                                             |Curated Web|
# 19                                            |Marketplaces|Art|E-Commerce|
# 25                                                            |Hospitality|
# 30                             |Social Commerce|E-Commerce|Mobile Commerce|
# 35                                                              |Education|
# ...                                                                     ...
# 47707                                                          |E-Commerce|
# 47712                                                                   NaN
# 47729  |Meeting Software|Polling|Surveys|Android|iPhone|iPad|Events|Mobile|
# 47743                                       |Networking|Web Hosting|Mobile|
# 47756                                                               |Games|
#
#                   market funding_total_usd     status country_code state_code  \
# 8            Curated Web        2 000 000   operating          NaN        NaN
# 19          Marketplaces          500 000    acquired          NaN        NaN
# 25           Hospitality        3 000 000   operating          NaN        NaN
# 30      Mobile Commerce         1 600 000         NaN          NaN        NaN
# 35             Education              -     operating          NaN        NaN
# ...                  ...               ...        ...          ...        ...
# 47707        E-Commerce               -     operating          NaN        NaN
# 47712                NaN           25 000   operating          NaN        NaN
# 47729           Polling           100 000   operating          NaN        NaN
# 47743       Web Hosting               -     operating          NaN        NaN
# 47756             Games         9 300 000   operating          NaN        NaN
#
#       region_x  ... alpha-3  country-code iso_3166-2 region_y sub-region  \
# 8          NaN  ...     NaN           NaN        NaN      NaN        NaN
# 19         NaN  ...     NaN           NaN        NaN      NaN        NaN
# 25         NaN  ...     NaN           NaN        NaN      NaN        NaN
# 30         NaN  ...     NaN           NaN        NaN      NaN        NaN
# 35         NaN  ...     NaN           NaN        NaN      NaN        NaN
# ...        ...  ...     ...           ...        ...      ...        ...
# 47707      NaN  ...     NaN           NaN        NaN      NaN        NaN
# 47712      NaN  ...     NaN           NaN        NaN      NaN        NaN
# 47729      NaN  ...     NaN           NaN        NaN      NaN        NaN
# 47743      NaN  ...     NaN           NaN        NaN      NaN        NaN
# 47756      NaN  ...     NaN           NaN        NaN      NaN        NaN
#
#        intermediate-region region-code sub-region-code  \
# 8                      NaN         NaN             NaN
# 19                     NaN         NaN             NaN
# 25                     NaN         NaN             NaN
# 30                     NaN         NaN             NaN
# 35                     NaN         NaN             NaN
# ...                    ...         ...             ...
# 47707                  NaN         NaN             NaN
# 47712                  NaN         NaN             NaN
# 47729                  NaN         NaN             NaN
# 47743                  NaN         NaN             NaN
# 47756                  NaN         NaN             NaN
#
#       intermediate-region-code     _merge
# 8                          NaN  left_only
# 19                         NaN  left_only
# 25                         NaN  left_only
# 30                         NaN  left_only
# 35                         NaN  left_only
# ...                        ...        ...
# 47707                      NaN  left_only
# 47712                      NaN  left_only
# 47729                      NaN  left_only
# 47743                      NaN  left_only
# 47756                      NaN  left_only
#
# [5164 rows x 30 columns]

# %% [markdown]
# ## Record Linking: Working around the Errors
#
# Rather than figuring out how to clean these characters, we'll instead look at doing approximate matching.

# %% [markdown]
# Now we'll need to import some similarity matching code, to do approximate match between the original names and those returned by Wikipedia

# %%
# We are going to match the strings approximately, via "n-grams" or "q-grams" (sequences of n or q characters)
# Here it's five-grams

tok = sm.QgramTokenizer(qval=5,return_set=True)

# %%
# Now let's do a similarity join

# We'll reset the index, so there is a unique index field in the company_ceos_df dataframe
company_ceos_df.reset_index(inplace=True)

output_pairs = ssj.jaccard_join(company_ceos_df, exec_df, 'index', 'page', 'Executive', 'clean_name', tok, 0.35,
                                l_out_attrs=['Executive'], r_out_attrs=['name'])

output_pairs[output_pairs['_sim_score'] < 1.0]
# Out:
# /usr/local/lib/python3.7/dist-packages/py_stringsimjoin/utils/generic_helper.py:77: FutureWarning: In a future version of pandas all arguments of DataFrame.dropna will be keyword-only
#   subset=[join_attr])
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
#      _id  l_index                                            r_page  \
# 39    39       41  https://en.wikipedia.org/wiki/Ola_K%C3%A4llenius
# 49    49       51   https://en.wikipedia.org/wiki/B%C3%B6rje_Ekholm
# 125  125      130   https://en.wikipedia.org/wiki/Michael_O%27Leary
#
#          l_Executive              r_name  _sim_score
# 39     Ola Källenius  Ola_K%C3%A4llenius    0.444444
# 49      Börje Ekholm   B%C3%B6rje_Ekholm    0.423077
# 125  Michael O'Leary   Michael_O%27Leary    0.538462

# %%
# At last! Company info + CEO info, together!

total = company_ceos_df.merge(output_pairs,left_on=['Executive'],right_on=['l_Executive']).\
        merge(exec_df,left_on=['r_page'],right_on=['page']).\
        merge(company_data_df, left_on='Company', right_on='name', how="left")

total
# Out:
#      index                    Company             Executive  \
# 0        0                  Accenture           Julie Sweet
# 1        1         Aditya Birla Group  Kumar Mangalam Birla
# 2        2              Adobe Systems      Shantanu Narayen
# 3        3                     Agenus         Garo H. Armen
# 4        4                     Airbus       Guillaume Faury
# ..     ...                        ...                   ...
# 171    177            Williams-Sonoma        Laura J. Alber
# 172    179                        WWE     Stephanie McMahon
# 173    180                Yum! Brands            Greg Creed
# 174    181               Zillow Group           Rich Barton
# 175    182  Zoom Video Communications             Eric Yuan
#
#                                                  Title    Since  \
# 0                                               CEO[1]     2019
# 1                                          Chairman[2]  1995[2]
# 2                       Chairman, president and CEO[3]     2007
# 3                            Founder, chairman, CEO[4]     1994
# 4                                               CEO[5]     2012
# ..                                                 ...      ...
# 171                             President and CEO[160]     2010
# 172  Chairwoman and Co-CEO (Alongside Nick Khan) [162]     2022
# 173                                           CEO[163]     2015
# 174                                           CEO[164]     2019
# 175                   President, Chairman and CEO[165]     2011
#
#                                                                                           Notes  \
# 0                                                               Succeeded Pierre Nanterme, died
# 1                                              Part of the Birla family business house in India
# 2                                                                           Formerly with Apple
# 3                                                Founder of the Children of Armenia Fund (COAF)
# 4                                                                       Succeeded Louis Gallois
# ..                                                                                          ...
# 171                                                                   Replaced W. Howard Lester
# 172           Chairwoman of the executive committeeChairwoman since 2022 CEO since July 22 2022
# 173                                                                Previously CEO for Taco Bell
# 174  Co-founder and previously was Zillow's CEO for nearly a decade. Succeeded Spencer Rascoff.
# 175                                 Previously corporate Vice President of engineering at Cisco
#
#         Updated  _id  l_index  \
# 0    2019-01-31    0        0
# 1    2018-10-01    1        1
# 2    2018-10-01    2        2
# 3    2018-10-01    3        3
# 4    2017-11-14    4        4
# ..          ...  ...      ...
# 171  2017-11-11  171      177
# 172  2017-11-11  172      179
# 173  2017-11-11  173      180
# 174  2018-12-10  174      181
# 175  2020-10-12  175      182
#
#                                                  r_page  ... state_code  \
# 0             https://en.wikipedia.org/wiki/Julie_Sweet  ...        NaN
# 1    https://en.wikipedia.org/wiki/Kumar_Mangalam_Birla  ...        NaN
# 2        https://en.wikipedia.org/wiki/Shantanu_Narayen  ...        NaN
# 3           https://en.wikipedia.org/wiki/Garo_H._Armen  ...         MA
# 4         https://en.wikipedia.org/wiki/Guillaume_Faury  ...        NaN
# ..                                                  ...  ...        ...
# 171        https://en.wikipedia.org/wiki/Laura_J._Alber  ...        NaN
# 172     https://en.wikipedia.org/wiki/Stephanie_McMahon  ...        NaN
# 173            https://en.wikipedia.org/wiki/Greg_Creed  ...        NaN
# 174           https://en.wikipedia.org/wiki/Rich_Barton  ...        NaN
# 175             https://en.wikipedia.org/wiki/Eric_Yuan  ...        NaN
#
#      region       city funding_rounds  founded_at founded_month  \
# 0       NaN        NaN            NaN         NaN           NaN
# 1       NaN        NaN            NaN         NaN           NaN
# 2       NaN        NaN            NaN         NaN           NaN
# 3    Boston  Lexington            2.0  01/01/1994       1994-01
# 4       NaN        NaN            NaN         NaN           NaN
# ..      ...        ...            ...         ...           ...
# 171     NaN        NaN            NaN         NaN           NaN
# 172     NaN        NaN            NaN         NaN           NaN
# 173     NaN        NaN            NaN         NaN           NaN
# 174     NaN        NaN            NaN         NaN           NaN
# 175     NaN        NaN            NaN         NaN           NaN
#
#     founded_quarter founded_year first_funding_at last_funding_at
# 0               NaN          NaN              NaN             NaN
# 1               NaN          NaN              NaN             NaN
# 2               NaN          NaN              NaN             NaN
# 3           1994-Q1       1994.0       04/08/2009      25/04/2013
# 4               NaN          NaN              NaN             NaN
# ..              ...          ...              ...             ...
# 171             NaN          NaN              NaN             NaN
# 172             NaN          NaN              NaN             NaN
# 173             NaN          NaN              NaN             NaN
# 174             NaN          NaN              NaN             NaN
# 175             NaN          NaN              NaN             NaN
#
# [176 rows x 35 columns]

# %%
# Let's get ready to plot

# %matplotlib inline

# %%
total
# Out:
#      index                    Company             Executive  \
# 0        0                  Accenture           Julie Sweet
# 1        1         Aditya Birla Group  Kumar Mangalam Birla
# 2        2              Adobe Systems      Shantanu Narayen
# 3        3                     Agenus         Garo H. Armen
# 4        4                     Airbus       Guillaume Faury
# ..     ...                        ...                   ...
# 171    177            Williams-Sonoma        Laura J. Alber
# 172    179                        WWE     Stephanie McMahon
# 173    180                Yum! Brands            Greg Creed
# 174    181               Zillow Group           Rich Barton
# 175    182  Zoom Video Communications             Eric Yuan
#
#                                                  Title    Since  \
# 0                                               CEO[1]     2019
# 1                                          Chairman[2]  1995[2]
# 2                       Chairman, president and CEO[3]     2007
# 3                            Founder, chairman, CEO[4]     1994
# 4                                               CEO[5]     2012
# ..                                                 ...      ...
# 171                             President and CEO[160]     2010
# 172  Chairwoman and Co-CEO (Alongside Nick Khan) [162]     2022
# 173                                           CEO[163]     2015
# 174                                           CEO[164]     2019
# 175                   President, Chairman and CEO[165]     2011
#
#                                                                                           Notes  \
# 0                                                               Succeeded Pierre Nanterme, died
# 1                                              Part of the Birla family business house in India
# 2                                                                           Formerly with Apple
# 3                                                Founder of the Children of Armenia Fund (COAF)
# 4                                                                       Succeeded Louis Gallois
# ..                                                                                          ...
# 171                                                                   Replaced W. Howard Lester
# 172           Chairwoman of the executive committeeChairwoman since 2022 CEO since July 22 2022
# 173                                                                Previously CEO for Taco Bell
# 174  Co-founder and previously was Zillow's CEO for nearly a decade. Succeeded Spencer Rascoff.
# 175                                 Previously corporate Vice President of engineering at Cisco
#
#         Updated  _id  l_index  \
# 0    2019-01-31    0        0
# 1    2018-10-01    1        1
# 2    2018-10-01    2        2
# 3    2018-10-01    3        3
# 4    2017-11-14    4        4
# ..          ...  ...      ...
# 171  2017-11-11  171      177
# 172  2017-11-11  172      179
# 173  2017-11-11  173      180
# 174  2018-12-10  174      181
# 175  2020-10-12  175      182
#
#                                                  r_page  ... state_code  \
# 0             https://en.wikipedia.org/wiki/Julie_Sweet  ...        NaN
# 1    https://en.wikipedia.org/wiki/Kumar_Mangalam_Birla  ...        NaN
# 2        https://en.wikipedia.org/wiki/Shantanu_Narayen  ...        NaN
# 3           https://en.wikipedia.org/wiki/Garo_H._Armen  ...         MA
# 4         https://en.wikipedia.org/wiki/Guillaume_Faury  ...        NaN
# ..                                                  ...  ...        ...
# 171        https://en.wikipedia.org/wiki/Laura_J._Alber  ...        NaN
# 172     https://en.wikipedia.org/wiki/Stephanie_McMahon  ...        NaN
# 173            https://en.wikipedia.org/wiki/Greg_Creed  ...        NaN
# 174           https://en.wikipedia.org/wiki/Rich_Barton  ...        NaN
# 175             https://en.wikipedia.org/wiki/Eric_Yuan  ...        NaN
#
#      region       city funding_rounds  founded_at founded_month  \
# 0       NaN        NaN            NaN         NaN           NaN
# 1       NaN        NaN            NaN         NaN           NaN
# 2       NaN        NaN            NaN         NaN           NaN
# 3    Boston  Lexington            2.0  01/01/1994       1994-01
# 4       NaN        NaN            NaN         NaN           NaN
# ..      ...        ...            ...         ...           ...
# 171     NaN        NaN            NaN         NaN           NaN
# 172     NaN        NaN            NaN         NaN           NaN
# 173     NaN        NaN            NaN         NaN           NaN
# 174     NaN        NaN            NaN         NaN           NaN
# 175     NaN        NaN            NaN         NaN           NaN
#
#     founded_quarter founded_year first_funding_at last_funding_at
# 0               NaN          NaN              NaN             NaN
# 1               NaN          NaN              NaN             NaN
# 2               NaN          NaN              NaN             NaN
# 3           1994-Q1       1994.0       04/08/2009      25/04/2013
# 4               NaN          NaN              NaN             NaN
# ..              ...          ...              ...             ...
# 171             NaN          NaN              NaN             NaN
# 172             NaN          NaN              NaN             NaN
# 173             NaN          NaN              NaN             NaN
# 174             NaN          NaN              NaN             NaN
# 175             NaN          NaN              NaN             NaN
#
# [176 rows x 35 columns]

# %% [markdown]
# ## Simple Analysis of Linked Data: Grouping and Analytics
#
# The `groupby` command allows us to coalesce data by groups.  In Pandas a Group is a special object with a set of rows.  We can see this with the `get_group` command.

# %%
total[['born','Company','Executive']].sort_values('born')
# Out:
#                     born                     Company        Executive
# 72   1576-02-29 00:00:00  Hewlett Packard Enterprise     Antonio Neri
# 71   1928-03-07 00:00:00  Henderson Land Development     Lee Shau Kee
# 19   1930-08-30 00:00:00          Berkshire Hathaway   Warren Buffett
# 74   1934-12-14 00:00:00                     HP Hood    John A. Kaneb
# 85   1935-11-01 00:00:00             Koch Industries  Charles G. Koch
# ..                   ...                         ...              ...
# 167                  NaN             Warner Brothers      Ann Sarnoff
# 170                  NaN          Whole Foods Market      John Mackey
# 171                  NaN             Williams-Sonoma   Laura J. Alber
# 173                  NaN                 Yum! Brands       Greg Creed
# 174                  NaN                Zillow Group      Rich Barton
#
# [176 rows x 3 columns]

# %%
total.groupby(by='born').get_group(datetime.datetime.strptime('1935-11-01', '%Y-%m-%d'))[['Company','Executive','born']]
# Out:
#             Company        Executive                 born
# 85  Koch Industries  Charles G. Koch  1935-11-01 00:00:00

# %% [markdown]
# We can apply computations, such as `count`, to the items in the group.  Values that are empty (NaN) do not count (no pun intended).

# %%
total.groupby(by='born').count()
# Out:
#                      index  Company  Executive  Title  Since  Notes  Updated  \
# born
# 1576-02-29 00:00:00      1        1          1      1      1      1        1
# 1928-03-07 00:00:00      1        1          1      1      1      1        1
# 1930-08-30 00:00:00      1        1          1      1      1      1        1
# 1934-12-14 00:00:00      1        1          1      1      1      1        1
# 1935-11-01 00:00:00      1        1          1      1      1      1        1
# ...                    ...      ...        ...    ...    ...    ...      ...
# 1976-09-24 00:00:00      1        1          1      1      1      1        1
# 1980-05-04 00:00:00      1        1          1      1      1      1        1
# 1984-05-14 00:00:00      1        1          1      1      1      1        1
# 1984-05-21 00:00:00      1        1          1      1      1      1        1
# 1992-01-24 00:00:00      1        1          1      1      1      1        1
#
#                      _id  l_index  r_page  ...  state_code  region  city  \
# born                                       ...
# 1576-02-29 00:00:00    1        1       1  ...           0       0     0
# 1928-03-07 00:00:00    1        1       1  ...           0       0     0
# 1930-08-30 00:00:00    1        1       1  ...           0       0     0
# 1934-12-14 00:00:00    1        1       1  ...           0       0     0
# 1935-11-01 00:00:00    1        1       1  ...           0       0     0
# ...                  ...      ...     ...  ...         ...     ...   ...
# 1976-09-24 00:00:00    1        1       1  ...           0       0     0
# 1980-05-04 00:00:00    1        1       1  ...           0       0     0
# 1984-05-14 00:00:00    1        1       1  ...           1       1     1
# 1984-05-21 00:00:00    1        1       1  ...           1       1     1
# 1992-01-24 00:00:00    1        1       1  ...           0       0     0
#
#                      funding_rounds  founded_at  founded_month  \
# born
# 1576-02-29 00:00:00               0           0              0
# 1928-03-07 00:00:00               0           0              0
# 1930-08-30 00:00:00               0           0              0
# 1934-12-14 00:00:00               0           0              0
# 1935-11-01 00:00:00               0           0              0
# ...                             ...         ...            ...
# 1976-09-24 00:00:00               0           0              0
# 1980-05-04 00:00:00               0           0              0
# 1984-05-14 00:00:00               1           1              1
# 1984-05-21 00:00:00               1           1              1
# 1992-01-24 00:00:00               0           0              0
#
#                      founded_quarter  founded_year  first_funding_at  \
# born
# 1576-02-29 00:00:00                0             0                 0
# 1928-03-07 00:00:00                0             0                 0
# 1930-08-30 00:00:00                0             0                 0
# 1934-12-14 00:00:00                0             0                 0
# 1935-11-01 00:00:00                0             0                 0
# ...                              ...           ...               ...
# 1976-09-24 00:00:00                0             0                 0
# 1980-05-04 00:00:00                0             0                 0
# 1984-05-14 00:00:00                1             1                 1
# 1984-05-21 00:00:00                1             1                 1
# 1992-01-24 00:00:00                0             0                 0
#
#                      last_funding_at
# born
# 1576-02-29 00:00:00                0
# 1928-03-07 00:00:00                0
# 1930-08-30 00:00:00                0
# 1934-12-14 00:00:00                0
# 1935-11-01 00:00:00                0
# ...                              ...
# 1976-09-24 00:00:00                0
# 1980-05-04 00:00:00                0
# 1984-05-14 00:00:00                1
# 1984-05-21 00:00:00                1
# 1992-01-24 00:00:00                0
#
# [104 rows x 34 columns]

# %%
# We can do this in SQL too...

### Until pandas 0.15, there is a bug in converting datetimes to sqllite
### so we have to copy to a string instead
total2 = total.copy()
total2['born'] = total2['born'].apply(lambda x: str(x))

total2.to_sql('total_info', conn, if_exists='replace', index=False)

# By default, SQL will include the Nan value (called NULL in SQL).  If we want to exclude it,
# we need to include WHERE ... IS NOT NULL.

pd.read_sql('select born, count(Company) from total_info ' +\
            'where born is not null group by born', conn)
# Out:
#                     born  count(Company)
# 0    1576-02-29 00:00:00               1
# 1    1928-03-07 00:00:00               1
# 2    1930-08-30 00:00:00               1
# 3    1934-12-14 00:00:00               1
# 4    1935-11-01 00:00:00               1
# ..                   ...             ...
# 101  1984-05-14 00:00:00               1
# 102  1984-05-21 00:00:00               1
# 103  1992-01-24 00:00:00               1
# 104                  NaT              28
# 105                  nan              43
#
# [106 rows x 2 columns]

# %%
total2 = total.dropna()
total2['born'] = total2['born'].astype('datetime64[ns]')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# dtype('<M8[ns]')

# %%
# Let's look at when the CEOs were born

birthdays = total2.groupby(by='born').count()[['Executive']]
birthdays.index = pd.to_datetime(birthdays.index, unit='s')

birthdays
# Out:
#             Executive
# born
# 1953-01-31          1
# 1953-12-27          1
# 1959-06-28          1
# 1961-03-11          1
# 1965-06-23          1
# 1966-02-08          1
# 1972-06-10          1
# 1984-05-14          1
# 1984-05-21          1

# %% [markdown]
# We can actually use `resample` over dates, with a parameter, to group eg by decade (10 years, where A is the code for year):

# %%
birthdays.resample('10A').count().plot(kind='bar')

# %% [markdown]
# Maybe that's a little weird.  Can we do something more along the lines of what we expect, i.e., "1920s, 1930s, ..."?

# %%
# Get rid of the nulls!
bdays = total[['born']].dropna()

bdays = bdays.applymap(lambda bday: str(int(bday.year / 10) * 10) + 's')

bdays.reset_index().groupby('born').count().plot(kind='bar')

# %% [markdown]
# # An Exercise
#
# Is there a correlation between the kind of company and the age of the CEO?
#
# Does the company's line of business matter?
